# %% [markdown]
# # Part 1) Supervised Learning Task. Training.

# %% [markdown]
# - **GOAL**: train a Neural Network to predict the actions of a mid-level player (classification task)
# <br>
# - **ABOUT THE TRAINING DATA:**
#     - our mid-level player is a _1StepLookaheadAgent_ instance
#     - the training data is a set of (_obs_, _action_) pairs:
#          - _obs_ is a game board where 1 is the active player and -1 is the oppponent
#          - _action_ is the column that a professional player will choose to play in _obs_
#     - Our supervised learning task: given an '*obs*' (game board), predict '*action*' (classification)
#     - To know more about the dataset creation, refer to '*src/data/part1_dataset_generator.ipynb*'
#     - the dataset used here can be found in: '*src/data/part1_data/part1_supervised_learning_data.txt*'
# <br>
# - **DATA PREPROCESSING:**
#     - To understand our implementation refer to *'src/models/custom_network.py'*
#     - the state of the environment is a _6 x 7_ board with values: {0: empty, 1: player, -1: opponent}
#     - The input of the model is a onehot encoded version of shape *2 x 6 x 7*
#         - first channel: {1: player, 0: empty or opponent}
#         - second channel: {1: opponent, 0: empty or player}
#     - For each channel, the empty positions that can be filled in the current turn are set to -1
# <br>
# - **NETWORK ARCHITECTURE:**
#     - To understand our implementation refer to *'src/models/custom_network.py'*
#     - We have implemented a basic network structure that allows different degrees of complexity
#     - The number of trainable parameters indicate the complexity of the network
#     - The name of this general architecture is _'CNET\<*N*\>_', where 'N' is the number of convolutional filters and hidden units
#     - **!!!!!** We implemented a **two-headed network achitecture** because some of the Deep Reinforcement Learning algorithms that we will implement later require two different prediction heads and are based on the network trained here. However, **the second head is NOT trained for this supervised learning task, only the first head**.
#     - The kernel sizes (4x4 and 2x2) and the size of the output (7) are fixed (do not depend on '*N*')
#     - For instance, the hidden layers of '_CNET*128*_' are:
#         - 2Dconvolutional layer with *128* 4x4 filters  (backbone network)
#         - 2Dconvolutional layer with *128* 2x2 filters  (backbone network)
#         - fully connected layer with *128* units   (backbone network)
#         - fully connected layer with *128* units (first prediction head) -> outputs the POLICY
#         - [NOT TRAINED HERE] fully connected layer with *128* units (second prediction head)
#     - For the general case _'CNET\<*N*\>_', change the number '128' to \<N\>
# <br>
# - **TRAINING STEPS:**
#     - Load the 200k data pairs (_obs, action_) from '*src/data/part1_data/part1_supervised_learning_data.txt*'
#     - trainig-validation-test data split: 160k + 20k + 20k samples (respectively)
#     - The following training parameters are the same for the all the networks:
#         - number of epochs = 20
#         - batch size = 64
#         - learning rate = 5e-4
#         - Loss function = Cross Entropy Loss
#         - weight decay (L2 regularization) = 2e-3
#     - Every 600 updates, we evaluate the model on the validation data
#     - When the training ends, we evaluate the model on the test data
#
# - **RESULTS**:
#     - We used the network architecture 'CNET128' (defined above and in the code as well)
#     - After training for 20 epochs and using the training hyper-parameter values described above:
#         - ~87% training accuracy
#         - ~85% validation accuracy
#         - ~85% test accuracy
#         - minimum overfitting
#     - At the end of the training loop, the training and validation accuracies and losses are plotted
#     - The architecture CNET128 is saved in '*src/models/architectures/cnet128.json*'
#     - The best weights are saved in: '*src/models/saved_models/supervised_cnet128.pt*'
#     - The training hyper-parameters are saved in: '*src/models/saved_models/supervised_cnet128_hparams.json*'

# %% [markdown]
# ## 1) Imports

# %%
import sys
import os
import math
import copy
from datetime import datetime
from pathlib import Path

import torch
import torch.nn as nn
import numpy as np
from torchsummary import summary
import matplotlib.pyplot as plt
from torch.utils.data.sampler import BatchSampler, SubsetRandomSampler

# Auto-detect project root
root = Path(os.getcwd()).parents[1]
if str(root) not in sys.path:
    sys.path.append(str(root))
    print(f"Added {root} to sys.path")
# Out:
# Added /home/luiscunha/AR to sys.path

# %%
from connect4_rl.agents.training.custom_net import CustomNetwork
from connect4_rl.envs.connect_four import ConnectFourEnv, get_illegal_actions

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## 2) Hyper parameters

# %%
hparams = {
    # where the data is located
    'data_file_path': '../../data/external/part1_supervised_learning_data.txt',
    
    # network architecture
    'network_arch': {
        'conv_block': [[128,4,0], 'relu', [128,2,0], 'relu'],
        'fc_block': [128, 'relu'],
        'first_head': [128, 'relu', 7],
        'second_head': [128, 'relu', 1]
    },
    'model_name': 'cnet128',

    # train-test split (sizes)
    'train_size': 160000,
    'val_size': 20000,
    'test_size': 20000,

    # Training params
    'num_epochs': 20,
    'batch_size': 64,
    'loss_log_every': 200,
    'validation_every': 600,
    'weight_decay': 2e-3,
    'lr': 5e-4,
    
    # save models
    'save_model': True,  # debug mode
    'save_model_file_path': '../../models/pretrained/novo/weights/supervised_{model_name}.pt'
}


hparams['save_model_file_path'] = hparams['save_model_file_path'].format(model_name=hparams['model_name'])
hparams['n_samples'] = hparams['train_size'] + hparams['val_size'] + hparams['test_size']

# %% [markdown]
# ## 3) Create the model

# %%
model = CustomNetwork(**hparams['network_arch']).to(device)
print(summary(model, input_size=model.input_shape))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 128, 3, 4]           4,224
#               ReLU-2            [-1, 128, 3, 4]               0
#             Conv2d-3            [-1, 128, 2, 3]          65,664
#               ReLU-4            [-1, 128, 2, 3]               0
#             Linear-5                  [-1, 128]          98,432
#               ReLU-6                  [-1, 128]               0
#             Linear-7                  [-1, 128]          16,512
#               ReLU-8                  [-1, 128]               0
#             Linear-9                    [-1, 7]             903
#            Linear-10                  [-1, 128]          16,512
#              ReLU-11                  [-1, 128]               0
#            Linear-12                    [-1, 1]             129
# ================================================================
# Total params: 202,376
# Trainable params: 202,376
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.04
# Params size (MB): 0.77
# Estimated Total Size (MB): 0.81
# ----------------------------------------------------------------
# None
# /home/luiscunha/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,

# %%
optimizer = torch.optim.Adam(
    params=model.parameters(),
    lr=hparams['lr'],
    weight_decay=hparams['weight_decay']
)

# %% [markdown]
# ## 4) Preprocess the data

# %%
# read the data
sep = ';'

with open(hparams['data_file_path'], 'r') as file:
    lines = file.read().split(sep)[:-1]  # last line is ''
assert hparams['n_samples'] <= len(lines), f'not enough data: {hparams["n_samples"]} > {len(lines)}'

obs_list, actions_list = [], []
for line in lines[:hparams['n_samples']]:
    flat_obs = [int(i) for i in line[:-1]]
    obs = np.array(flat_obs).reshape((6,7))
    obs[obs==2] = -1
    obs_list.append(obs)
    actions_list.append(int(line[-1]))

print(f"{len(obs_list)} data samples loaded from '{hparams['data_file_path']}'")
# Out:
# 200000 data samples loaded from '../../data/external/part1_supervised_learning_data.txt'

# %%
# turn the data points into pytorch tensors to feed the model

obs_tensor = torch.cat([model.obs_to_model_input(obs=o) for o in obs_list])
actions_tensor = torch.tensor(actions_list, dtype=torch.long)

# train-val-test split
data_idx = random.sample(range(len(obs_list)), k=hparams['n_samples'])
train_idx = data_idx[:hparams['train_size']]
val_idx = data_idx[hparams['train_size']:-hparams['test_size']]
test_idx = data_idx[-hparams['test_size']:]

# train_x and train_y will be moved to device in batches while training
train_x = obs_tensor[train_idx]
train_y = actions_tensor[train_idx]

val_x = obs_tensor[val_idx].to(device)
val_y = actions_tensor[val_idx].to(device)

test_x = obs_tensor[test_idx].to(device)
test_y = actions_tensor[test_idx].to(device)

print(f'train: {train_x.shape},  {train_y.shape}')
print(f'val: {val_x.shape},  {val_y.shape}')
print(f'test:  {test_x.shape},  {test_y.shape}')
# Out:
# train: torch.Size([160000, 2, 6, 7]),  torch.Size([160000])
# val: torch.Size([20000, 2, 6, 7]),  torch.Size([20000])
# test:  torch.Size([20000, 2, 6, 7]),  torch.Size([20000])

# %% [markdown]
# ## 5) Training loop

# %%
loss_func = torch.nn.CrossEntropyLoss()

# %%
def accuracy(output: torch.tensor, labels: torch.tensor):
    """
    Computes the accuracy of the given predictions
    
    :param output: network output (predictions)
    :param labels: ground truth
    """
    
    pred_y = torch.max(output, 1)[1].data.squeeze()
    acc = torch.sum(pred_y == labels).item() / float(labels.size(0))
    return acc


def validate():
    """
    Validate the model on the validation data: global val_x and val_y
    Returns the valiation loss and validation accuracy
    """
    
    is_training = model.training
    model.eval()
    
    with torch.no_grad():
        val_pred, _ = model(val_x)
        val_loss = loss_func(val_pred, val_y)
        val_acc = accuracy(output=val_pred, labels=val_y)
    
    if is_training:
        model.train()
    
    return val_loss.item(), val_acc


def test():
    """
    Test the model on the test data: global test_x and test_y
    Returns the test loss and test accuracy
    """
    
    is_training = model.training
    model.eval()
    
    with torch.no_grad():
        test_pred, _ = model(test_x)
        test_loss = loss_func(test_pred, test_y)
        test_acc = accuracy(output=test_pred, labels=test_y)
    
    if is_training:
        model.train()
    
    return test_loss.item(), test_acc

# %%
history = {'loss': [], 'acc': [], 
           'val_loss': [], 'val_acc': [],
           'test_loss': 0, 'test_acc': 0}

env = ConnectFourEnv()

model.train()

num_epoch_steps = int(np.ceil(len(train_x)/hparams['batch_size']))
step_count = 0
for epoch in range(hparams['num_epochs']):
    
    epoch_step = 0
    index_list = SubsetRandomSampler(range(len(train_x)))
    for batch_index in BatchSampler(index_list, hparams['batch_size'], False):

        batch_x = train_x[batch_index].to(device)
        batch_y = train_y[batch_index].to(device)

        batch_pred, _ = model(batch_x)
        loss = loss_func(batch_pred, batch_y)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        history['loss'].append(loss.item())
        history['acc'].append(accuracy(batch_pred.detach(), batch_y))

        step_count += 1
        epoch_step += 1

        if step_count % hparams['loss_log_every'] == 0:
            avg_loss = float(np.mean(history['loss'][-hparams['loss_log_every']]))
            avg_acc = float(np.mean(history['acc'][-hparams['loss_log_every']]))
            print(f'Epoch: {epoch+1}/{hparams["num_epochs"]},    ' +
                  f'{epoch_step}/{num_epoch_steps} steps,    ' +
                  f'avg_loss={round(avg_loss, 3)},    ' +
                  f'avg_acc={round(avg_acc, 3)}')

        if step_count % hparams['validation_every'] == 0:
            val_loss, val_acc = validate()
            history['val_loss'].append(val_loss)
            history['val_acc'].append(val_acc)
            print(f'  --> val_loss={round(val_loss, 3)},   val_acc={round(val_acc, 3)}')
# Out:
# Epoch: 1/20,    200/2500 steps,    avg_loss=1.946,    avg_acc=0.188
# Epoch: 1/20,    400/2500 steps,    avg_loss=1.771,    avg_acc=0.297
# Epoch: 1/20,    600/2500 steps,    avg_loss=1.565,    avg_acc=0.438
#   --> val_loss=1.453,   val_acc=0.461
# Epoch: 1/20,    800/2500 steps,    avg_loss=1.455,    avg_acc=0.406
# Epoch: 1/20,    1000/2500 steps,    avg_loss=1.285,    avg_acc=0.547
# Epoch: 1/20,    1200/2500 steps,    avg_loss=1.241,    avg_acc=0.562
#   --> val_loss=1.265,   val_acc=0.532
# Epoch: 1/20,    1400/2500 steps,    avg_loss=1.218,    avg_acc=0.562
# Epoch: 1/20,    1600/2500 steps,    avg_loss=1.139,    avg_acc=0.609
# Epoch: 1/20,    1800/2500 steps,    avg_loss=1.216,    avg_acc=0.594
#   --> val_loss=1.144,   val_acc=0.573
# Epoch: 1/20,    2000/2500 steps,    avg_loss=1.023,    avg_acc=0.656
# Epoch: 1/20,    2200/2500 steps,    avg_loss=1.236,    avg_acc=0.531
# Epoch: 1/20,    2400/2500 steps,    avg_loss=1.069,    avg_acc=0.594
#   --> val_loss=1.057,   val_acc=0.607
# Epoch: 2/20,    100/2500 steps,    avg_loss=1.229,    avg_acc=0.516
# Epoch: 2/20,    300/2500 steps,    avg_loss=0.958,    avg_acc=0.609
# Epoch: 2/20,    500/2500 steps,    avg_loss=0.894,    avg_acc=0.641
#   --> val_loss=0.932,   val_acc=0.653
# Epoch: 2/20,    700/2500 steps,    avg_loss=0.94,    avg_acc=0.625
# Epoch: 2/20,    900/2500 steps,    avg_loss=0.869,    avg_acc=0.625
# Epoch: 2/20,    1100/2500 steps,    avg_loss=0.864,    avg_acc=0.641
#   --> val_loss=0.846,   val_acc=0.681
# Epoch: 2/20,    1300/2500 steps,    avg_loss=0.916,    avg_acc=0.641
# Epoch: 2/20,    1500/2500 steps,    avg_loss=0.987,    avg_acc=0.656
# Epoch: 2/20,    1700/2500 steps,    avg_loss=0.843,    avg_acc=0.672
#   --> val_loss=0.787,   val_acc=0.705
# Epoch: 2/20,    1900/2500 steps,    avg_loss=0.744,    avg_acc=0.719
# Epoch: 2/20,    2100/2500 steps,    avg_loss=0.783,    avg_acc=0.781
# Epoch: 2/20,    2300/2500 steps,    avg_loss=0.806,    avg_acc=0.688
#   --> val_loss=0.74,   val_acc=0.721
# Epoch: 2/20,    2500/2500 steps,    avg_loss=1.015,    avg_acc=0.641
# Epoch: 3/20,    200/2500 steps,    avg_loss=0.89,    avg_acc=0.609
# Epoch: 3/20,    400/2500 steps,    avg_loss=0.673,    avg_acc=0.703
#   --> val_loss=0.707,   val_acc=0.736
# Epoch: 3/20,    600/2500 steps,    avg_loss=0.692,    avg_acc=0.703
# Epoch: 3/20,    800/2500 steps,    avg_loss=0.615,    avg_acc=0.734
# Epoch: 3/20,    1000/2500 steps,    avg_loss=0.911,    avg_acc=0.656
#   --> val_loss=0.687,   val_acc=0.742
# Epoch: 3/20,    1200/2500 steps,    avg_loss=0.713,    avg_acc=0.734
# Epoch: 3/20,    1400/2500 steps,    avg_loss=0.534,    avg_acc=0.797
# Epoch: 3/20,    1600/2500 steps,    avg_loss=0.556,    avg_acc=0.781
#   --> val_loss=0.644,   val_acc=0.75
# Epoch: 3/20,    1800/2500 steps,    avg_loss=0.564,    avg_acc=0.766
# Epoch: 3/20,    2000/2500 steps,    avg_loss=0.618,    avg_acc=0.781
# Epoch: 3/20,    2200/2500 steps,    avg_loss=0.809,    avg_acc=0.734
#   --> val_loss=0.623,   val_acc=0.763
# Epoch: 3/20,    2400/2500 steps,    avg_loss=0.584,    avg_acc=0.766
# Epoch: 4/20,    100/2500 steps,    avg_loss=0.592,    avg_acc=0.781
# Epoch: 4/20,    300/2500 steps,    avg_loss=0.496,    avg_acc=0.828
#   --> val_loss=0.627,   val_acc=0.766
# Epoch: 4/20,    500/2500 steps,    avg_loss=0.581,    avg_acc=0.781
# Epoch: 4/20,    700/2500 steps,    avg_loss=0.644,    avg_acc=0.766
# Epoch: 4/20,    900/2500 steps,    avg_loss=0.643,    avg_acc=0.797
#   --> val_loss=0.581,   val_acc=0.782
# Epoch: 4/20,    1100/2500 steps,    avg_loss=0.492,    avg_acc=0.844
# Epoch: 4/20,    1300/2500 steps,    avg_loss=0.513,    avg_acc=0.812
# Epoch: 4/20,    1500/2500 steps,    avg_loss=0.557,    avg_acc=0.75
#   --> val_loss=0.567,   val_acc=0.788
# Epoch: 4/20,    1700/2500 steps,    avg_loss=0.589,    avg_acc=0.781
# Epoch: 4/20,    1900/2500 steps,    avg_loss=0.492,    avg_acc=0.797
# Epoch: 4/20,    2100/2500 steps,    avg_loss=0.554,    avg_acc=0.766
#   --> val_loss=0.556,   val_acc=0.787
# Epoch: 4/20,    2300/2500 steps,    avg_loss=0.427,    avg_acc=0.828
# Epoch: 4/20,    2500/2500 steps,    avg_loss=0.571,    avg_acc=0.812
# Epoch: 5/20,    200/2500 steps,    avg_loss=0.269,    avg_acc=0.906
#   --> val_loss=0.554,   val_acc=0.791
# Epoch: 5/20,    400/2500 steps,    avg_loss=0.512,    avg_acc=0.766
# Epoch: 5/20,    600/2500 steps,    avg_loss=0.679,    avg_acc=0.734
# Epoch: 5/20,    800/2500 steps,    avg_loss=0.591,    avg_acc=0.766
#   --> val_loss=0.528,   val_acc=0.799
# Epoch: 5/20,    1000/2500 steps,    avg_loss=0.385,    avg_acc=0.859
# Epoch: 5/20,    1200/2500 steps,    avg_loss=0.531,    avg_acc=0.828
# Epoch: 5/20,    1400/2500 steps,    avg_loss=0.589,    avg_acc=0.75
#   --> val_loss=0.534,   val_acc=0.795
# Epoch: 5/20,    1600/2500 steps,    avg_loss=0.497,    avg_acc=0.797
# Epoch: 5/20,    1800/2500 steps,    avg_loss=0.369,    avg_acc=0.891
# Epoch: 5/20,    2000/2500 steps,    avg_loss=0.329,    avg_acc=0.906
#   --> val_loss=0.514,   val_acc=0.8
# Epoch: 5/20,    2200/2500 steps,    avg_loss=0.445,    avg_acc=0.797
# Epoch: 5/20,    2400/2500 steps,    avg_loss=0.613,    avg_acc=0.75
# Epoch: 6/20,    100/2500 steps,    avg_loss=0.443,    avg_acc=0.781
#   --> val_loss=0.486,   val_acc=0.811
# Epoch: 6/20,    300/2500 steps,    avg_loss=0.444,    avg_acc=0.844
# Epoch: 6/20,    500/2500 steps,    avg_loss=0.453,    avg_acc=0.828
# Epoch: 6/20,    700/2500 steps,    avg_loss=0.386,    avg_acc=0.828
#   --> val_loss=0.492,   val_acc=0.809
# Epoch: 6/20,    900/2500 steps,    avg_loss=0.47,    avg_acc=0.844
# Epoch: 6/20,    1100/2500 steps,    avg_loss=0.568,    avg_acc=0.75
# Epoch: 6/20,    1300/2500 steps,    avg_loss=0.438,    avg_acc=0.828
#   --> val_loss=0.485,   val_acc=0.812
# Epoch: 6/20,    1500/2500 steps,    avg_loss=0.507,    avg_acc=0.797
# Epoch: 6/20,    1700/2500 steps,    avg_loss=0.438,    avg_acc=0.875
# Epoch: 6/20,    1900/2500 steps,    avg_loss=0.479,    avg_acc=0.828
#   --> val_loss=0.497,   val_acc=0.811
# Epoch: 6/20,    2100/2500 steps,    avg_loss=0.489,    avg_acc=0.812
# Epoch: 6/20,    2300/2500 steps,    avg_loss=0.583,    avg_acc=0.766
# Epoch: 6/20,    2500/2500 steps,    avg_loss=0.438,    avg_acc=0.875
#   --> val_loss=0.469,   val_acc=0.822
# Epoch: 7/20,    200/2500 steps,    avg_loss=0.317,    avg_acc=0.875
# Epoch: 7/20,    400/2500 steps,    avg_loss=0.404,    avg_acc=0.828
# Epoch: 7/20,    600/2500 steps,    avg_loss=0.482,    avg_acc=0.828
#   --> val_loss=0.465,   val_acc=0.822
# Epoch: 7/20,    800/2500 steps,    avg_loss=0.348,    avg_acc=0.891
# Epoch: 7/20,    1000/2500 steps,    avg_loss=0.419,    avg_acc=0.828
# Epoch: 7/20,    1200/2500 steps,    avg_loss=0.475,    avg_acc=0.812
#   --> val_loss=0.468,   val_acc=0.818
# Epoch: 7/20,    1400/2500 steps,    avg_loss=0.405,    avg_acc=0.859
# Epoch: 7/20,    1600/2500 steps,    avg_loss=0.496,    avg_acc=0.844
# Epoch: 7/20,    1800/2500 steps,    avg_loss=0.233,    avg_acc=0.938
#   --> val_loss=0.451,   val_acc=0.831
# Epoch: 7/20,    2000/2500 steps,    avg_loss=0.506,    avg_acc=0.844
# Epoch: 7/20,    2200/2500 steps,    avg_loss=0.3,    avg_acc=0.891
# Epoch: 7/20,    2400/2500 steps,    avg_loss=0.412,    avg_acc=0.797
#   --> val_loss=0.457,   val_acc=0.824
# Epoch: 8/20,    100/2500 steps,    avg_loss=0.248,    avg_acc=0.922
# Epoch: 8/20,    300/2500 steps,    avg_loss=0.374,    avg_acc=0.859
# Epoch: 8/20,    500/2500 steps,    avg_loss=0.38,    avg_acc=0.844
#   --> val_loss=0.447,   val_acc=0.828
# Epoch: 8/20,    700/2500 steps,    avg_loss=0.44,    avg_acc=0.844
# Epoch: 8/20,    900/2500 steps,    avg_loss=0.261,    avg_acc=0.906
# Epoch: 8/20,    1100/2500 steps,    avg_loss=0.436,    avg_acc=0.844
#   --> val_loss=0.45,   val_acc=0.825
# Epoch: 8/20,    1300/2500 steps,    avg_loss=0.222,    avg_acc=0.938
# Epoch: 8/20,    1500/2500 steps,    avg_loss=0.443,    avg_acc=0.844
# Epoch: 8/20,    1700/2500 steps,    avg_loss=0.493,    avg_acc=0.828
#   --> val_loss=0.438,   val_acc=0.831
# Epoch: 8/20,    1900/2500 steps,    avg_loss=0.378,    avg_acc=0.859
# Epoch: 8/20,    2100/2500 steps,    avg_loss=0.606,    avg_acc=0.734
# Epoch: 8/20,    2300/2500 steps,    avg_loss=0.479,    avg_acc=0.781
#   --> val_loss=0.432,   val_acc=0.835
# Epoch: 8/20,    2500/2500 steps,    avg_loss=0.353,    avg_acc=0.859
# Epoch: 9/20,    200/2500 steps,    avg_loss=0.377,    avg_acc=0.922
# Epoch: 9/20,    400/2500 steps,    avg_loss=0.414,    avg_acc=0.828
#   --> val_loss=0.434,   val_acc=0.832
# Epoch: 9/20,    600/2500 steps,    avg_loss=0.399,    avg_acc=0.859
# Epoch: 9/20,    800/2500 steps,    avg_loss=0.309,    avg_acc=0.891
# Epoch: 9/20,    1000/2500 steps,    avg_loss=0.429,    avg_acc=0.797
#   --> val_loss=0.436,   val_acc=0.83
# Epoch: 9/20,    1200/2500 steps,    avg_loss=0.4,    avg_acc=0.859
# Epoch: 9/20,    1400/2500 steps,    avg_loss=0.409,    avg_acc=0.859
# Epoch: 9/20,    1600/2500 steps,    avg_loss=0.331,    avg_acc=0.891
#   --> val_loss=0.427,   val_acc=0.836
# Epoch: 9/20,    1800/2500 steps,    avg_loss=0.413,    avg_acc=0.859
# Epoch: 9/20,    2000/2500 steps,    avg_loss=0.328,    avg_acc=0.828
# Epoch: 9/20,    2200/2500 steps,    avg_loss=0.282,    avg_acc=0.891
#   --> val_loss=0.414,   val_acc=0.841
# Epoch: 9/20,    2400/2500 steps,    avg_loss=0.513,    avg_acc=0.766
# Epoch: 10/20,    100/2500 steps,    avg_loss=0.297,    avg_acc=0.891
# Epoch: 10/20,    300/2500 steps,    avg_loss=0.235,    avg_acc=0.953
#   --> val_loss=0.414,   val_acc=0.84
# Epoch: 10/20,    500/2500 steps,    avg_loss=0.307,    avg_acc=0.891
# Epoch: 10/20,    700/2500 steps,    avg_loss=0.366,    avg_acc=0.891
# Epoch: 10/20,    900/2500 steps,    avg_loss=0.386,    avg_acc=0.844
#   --> val_loss=0.412,   val_acc=0.842
# Epoch: 10/20,    1100/2500 steps,    avg_loss=0.209,    avg_acc=0.953
# Epoch: 10/20,    1300/2500 steps,    avg_loss=0.287,    avg_acc=0.906
# Epoch: 10/20,    1500/2500 steps,    avg_loss=0.378,    avg_acc=0.891
#   --> val_loss=0.41,   val_acc=0.843
# Epoch: 10/20,    1700/2500 steps,    avg_loss=0.332,    avg_acc=0.859
# Epoch: 10/20,    1900/2500 steps,    avg_loss=0.3,    avg_acc=0.875
# Epoch: 10/20,    2100/2500 steps,    avg_loss=0.351,    avg_acc=0.891
#   --> val_loss=0.421,   val_acc=0.837
# Epoch: 10/20,    2300/2500 steps,    avg_loss=0.268,    avg_acc=0.938
# Epoch: 10/20,    2500/2500 steps,    avg_loss=0.28,    avg_acc=0.891
# Epoch: 11/20,    200/2500 steps,    avg_loss=0.235,    avg_acc=0.906
#   --> val_loss=0.424,   val_acc=0.834
# Epoch: 11/20,    400/2500 steps,    avg_loss=0.341,    avg_acc=0.906
# Epoch: 11/20,    600/2500 steps,    avg_loss=0.403,    avg_acc=0.828
# Epoch: 11/20,    800/2500 steps,    avg_loss=0.361,    avg_acc=0.891
#   --> val_loss=0.428,   val_acc=0.836
# Epoch: 11/20,    1000/2500 steps,    avg_loss=0.487,    avg_acc=0.812
# Epoch: 11/20,    1200/2500 steps,    avg_loss=0.404,    avg_acc=0.844
# Epoch: 11/20,    1400/2500 steps,    avg_loss=0.241,    avg_acc=0.938
#   --> val_loss=0.405,   val_acc=0.842
# Epoch: 11/20,    1600/2500 steps,    avg_loss=0.402,    avg_acc=0.875
# Epoch: 11/20,    1800/2500 steps,    avg_loss=0.305,    avg_acc=0.922
# Epoch: 11/20,    2000/2500 steps,    avg_loss=0.282,    avg_acc=0.891
#   --> val_loss=0.391,   val_acc=0.85
# Epoch: 11/20,    2200/2500 steps,    avg_loss=0.365,    avg_acc=0.875
# Epoch: 11/20,    2400/2500 steps,    avg_loss=0.343,    avg_acc=0.828
# Epoch: 12/20,    100/2500 steps,    avg_loss=0.304,    avg_acc=0.906
#   --> val_loss=0.402,   val_acc=0.845
# Epoch: 12/20,    300/2500 steps,    avg_loss=0.317,    avg_acc=0.891
# Epoch: 12/20,    500/2500 steps,    avg_loss=0.354,    avg_acc=0.844
# Epoch: 12/20,    700/2500 steps,    avg_loss=0.389,    avg_acc=0.844
#   --> val_loss=0.397,   val_acc=0.848
# Epoch: 12/20,    900/2500 steps,    avg_loss=0.391,    avg_acc=0.828
# Epoch: 12/20,    1100/2500 steps,    avg_loss=0.391,    avg_acc=0.875
# Epoch: 12/20,    1300/2500 steps,    avg_loss=0.313,    avg_acc=0.859
#   --> val_loss=0.389,   val_acc=0.851
# Epoch: 12/20,    1500/2500 steps,    avg_loss=0.37,    avg_acc=0.844
# Epoch: 12/20,    1700/2500 steps,    avg_loss=0.362,    avg_acc=0.922
# Epoch: 12/20,    1900/2500 steps,    avg_loss=0.244,    avg_acc=0.906
#   --> val_loss=0.401,   val_acc=0.846
# Epoch: 12/20,    2100/2500 steps,    avg_loss=0.419,    avg_acc=0.891
# Epoch: 12/20,    2300/2500 steps,    avg_loss=0.259,    avg_acc=0.906
# Epoch: 12/20,    2500/2500 steps,    avg_loss=0.238,    avg_acc=0.938
#   --> val_loss=0.41,   val_acc=0.84
# Epoch: 13/20,    200/2500 steps,    avg_loss=0.334,    avg_acc=0.875
# Epoch: 13/20,    400/2500 steps,    avg_loss=0.306,    avg_acc=0.875
# Epoch: 13/20,    600/2500 steps,    avg_loss=0.326,    avg_acc=0.906
#   --> val_loss=0.377,   val_acc=0.856
# Epoch: 13/20,    800/2500 steps,    avg_loss=0.29,    avg_acc=0.891
# Epoch: 13/20,    1000/2500 steps,    avg_loss=0.329,    avg_acc=0.859
# Epoch: 13/20,    1200/2500 steps,    avg_loss=0.285,    avg_acc=0.891
#   --> val_loss=0.397,   val_acc=0.844
# Epoch: 13/20,    1400/2500 steps,    avg_loss=0.299,    avg_acc=0.891
# Epoch: 13/20,    1600/2500 steps,    avg_loss=0.27,    avg_acc=0.938
# Epoch: 13/20,    1800/2500 steps,    avg_loss=0.382,    avg_acc=0.828
#   --> val_loss=0.383,   val_acc=0.851
# Epoch: 13/20,    2000/2500 steps,    avg_loss=0.338,    avg_acc=0.891
# Epoch: 13/20,    2200/2500 steps,    avg_loss=0.155,    avg_acc=0.953
# Epoch: 13/20,    2400/2500 steps,    avg_loss=0.377,    avg_acc=0.812
#   --> val_loss=0.387,   val_acc=0.85
# Epoch: 14/20,    100/2500 steps,    avg_loss=0.431,    avg_acc=0.797
# Epoch: 14/20,    300/2500 steps,    avg_loss=0.17,    avg_acc=0.969
# Epoch: 14/20,    500/2500 steps,    avg_loss=0.321,    avg_acc=0.891
#   --> val_loss=0.371,   val_acc=0.858
# Epoch: 14/20,    700/2500 steps,    avg_loss=0.445,    avg_acc=0.828
# Epoch: 14/20,    900/2500 steps,    avg_loss=0.334,    avg_acc=0.859
# Epoch: 14/20,    1100/2500 steps,    avg_loss=0.372,    avg_acc=0.859
#   --> val_loss=0.393,   val_acc=0.849
# Epoch: 14/20,    1300/2500 steps,    avg_loss=0.282,    avg_acc=0.922
# Epoch: 14/20,    1500/2500 steps,    avg_loss=0.411,    avg_acc=0.844
# Epoch: 14/20,    1700/2500 steps,    avg_loss=0.295,    avg_acc=0.922
#   --> val_loss=0.387,   val_acc=0.851
# Epoch: 14/20,    1900/2500 steps,    avg_loss=0.206,    avg_acc=0.938
# Epoch: 14/20,    2100/2500 steps,    avg_loss=0.281,    avg_acc=0.891
# Epoch: 14/20,    2300/2500 steps,    avg_loss=0.171,    avg_acc=0.953
#   --> val_loss=0.379,   val_acc=0.857
# Epoch: 14/20,    2500/2500 steps,    avg_loss=0.264,    avg_acc=0.859
# Epoch: 15/20,    200/2500 steps,    avg_loss=0.194,    avg_acc=0.922
# Epoch: 15/20,    400/2500 steps,    avg_loss=0.302,    avg_acc=0.922
#   --> val_loss=0.372,   val_acc=0.856
# Epoch: 15/20,    600/2500 steps,    avg_loss=0.343,    avg_acc=0.891
# Epoch: 15/20,    800/2500 steps,    avg_loss=0.304,    avg_acc=0.922
# Epoch: 15/20,    1000/2500 steps,    avg_loss=0.281,    avg_acc=0.906
#   --> val_loss=0.375,   val_acc=0.857
# Epoch: 15/20,    1200/2500 steps,    avg_loss=0.304,    avg_acc=0.938
# Epoch: 15/20,    1400/2500 steps,    avg_loss=0.302,    avg_acc=0.891
# Epoch: 15/20,    1600/2500 steps,    avg_loss=0.277,    avg_acc=0.891
#   --> val_loss=0.375,   val_acc=0.852
# Epoch: 15/20,    1800/2500 steps,    avg_loss=0.406,    avg_acc=0.828
# Epoch: 15/20,    2000/2500 steps,    avg_loss=0.306,    avg_acc=0.922
# Epoch: 15/20,    2200/2500 steps,    avg_loss=0.312,    avg_acc=0.922
#   --> val_loss=0.373,   val_acc=0.855
# Epoch: 15/20,    2400/2500 steps,    avg_loss=0.257,    avg_acc=0.906
# Epoch: 16/20,    100/2500 steps,    avg_loss=0.326,    avg_acc=0.906
# Epoch: 16/20,    300/2500 steps,    avg_loss=0.311,    avg_acc=0.891
#   --> val_loss=0.371,   val_acc=0.858
# Epoch: 16/20,    500/2500 steps,    avg_loss=0.198,    avg_acc=0.906
# Epoch: 16/20,    700/2500 steps,    avg_loss=0.164,    avg_acc=0.969
# Epoch: 16/20,    900/2500 steps,    avg_loss=0.508,    avg_acc=0.828
#   --> val_loss=0.372,   val_acc=0.855
# Epoch: 16/20,    1100/2500 steps,    avg_loss=0.303,    avg_acc=0.891
# Epoch: 16/20,    1300/2500 steps,    avg_loss=0.281,    avg_acc=0.875
# Epoch: 16/20,    1500/2500 steps,    avg_loss=0.355,    avg_acc=0.859
#   --> val_loss=0.363,   val_acc=0.86
# Epoch: 16/20,    1700/2500 steps,    avg_loss=0.357,    avg_acc=0.859
# Epoch: 16/20,    1900/2500 steps,    avg_loss=0.26,    avg_acc=0.906
# Epoch: 16/20,    2100/2500 steps,    avg_loss=0.344,    avg_acc=0.844
#   --> val_loss=0.362,   val_acc=0.863
# Epoch: 16/20,    2300/2500 steps,    avg_loss=0.304,    avg_acc=0.891
# Epoch: 16/20,    2500/2500 steps,    avg_loss=0.259,    avg_acc=0.938
# Epoch: 17/20,    200/2500 steps,    avg_loss=0.312,    avg_acc=0.891
#   --> val_loss=0.366,   val_acc=0.859
# Epoch: 17/20,    400/2500 steps,    avg_loss=0.348,    avg_acc=0.828
# Epoch: 17/20,    600/2500 steps,    avg_loss=0.271,    avg_acc=0.875
# Epoch: 17/20,    800/2500 steps,    avg_loss=0.247,    avg_acc=0.891
#   --> val_loss=0.353,   val_acc=0.867
# Epoch: 17/20,    1000/2500 steps,    avg_loss=0.382,    avg_acc=0.875
# Epoch: 17/20,    1200/2500 steps,    avg_loss=0.234,    avg_acc=0.922
# Epoch: 17/20,    1400/2500 steps,    avg_loss=0.229,    avg_acc=0.938
#   --> val_loss=0.359,   val_acc=0.864
# Epoch: 17/20,    1600/2500 steps,    avg_loss=0.278,    avg_acc=0.859
# Epoch: 17/20,    1800/2500 steps,    avg_loss=0.29,    avg_acc=0.891
# Epoch: 17/20,    2000/2500 steps,    avg_loss=0.321,    avg_acc=0.891
#   --> val_loss=0.363,   val_acc=0.861
# Epoch: 17/20,    2200/2500 steps,    avg_loss=0.356,    avg_acc=0.828
# Epoch: 17/20,    2400/2500 steps,    avg_loss=0.294,    avg_acc=0.875
# Epoch: 18/20,    100/2500 steps,    avg_loss=0.336,    avg_acc=0.859
#   --> val_loss=0.356,   val_acc=0.864
# Epoch: 18/20,    300/2500 steps,    avg_loss=0.34,    avg_acc=0.891
# Epoch: 18/20,    500/2500 steps,    avg_loss=0.19,    avg_acc=0.922
# Epoch: 18/20,    700/2500 steps,    avg_loss=0.228,    avg_acc=0.891
#   --> val_loss=0.371,   val_acc=0.855
# Epoch: 18/20,    900/2500 steps,    avg_loss=0.249,    avg_acc=0.938
# Epoch: 18/20,    1100/2500 steps,    avg_loss=0.402,    avg_acc=0.844
# Epoch: 18/20,    1300/2500 steps,    avg_loss=0.399,    avg_acc=0.766
#   --> val_loss=0.357,   val_acc=0.866
# Epoch: 18/20,    1500/2500 steps,    avg_loss=0.304,    avg_acc=0.859
# Epoch: 18/20,    1700/2500 steps,    avg_loss=0.386,    avg_acc=0.812
# Epoch: 18/20,    1900/2500 steps,    avg_loss=0.42,    avg_acc=0.875
#   --> val_loss=0.347,   val_acc=0.868
# Epoch: 18/20,    2100/2500 steps,    avg_loss=0.286,    avg_acc=0.891
# Epoch: 18/20,    2300/2500 steps,    avg_loss=0.293,    avg_acc=0.906
# Epoch: 18/20,    2500/2500 steps,    avg_loss=0.37,    avg_acc=0.812
#   --> val_loss=0.355,   val_acc=0.865
# Epoch: 19/20,    200/2500 steps,    avg_loss=0.355,    avg_acc=0.859
# Epoch: 19/20,    400/2500 steps,    avg_loss=0.264,    avg_acc=0.922
# Epoch: 19/20,    600/2500 steps,    avg_loss=0.328,    avg_acc=0.922
#   --> val_loss=0.363,   val_acc=0.858
# Epoch: 19/20,    800/2500 steps,    avg_loss=0.332,    avg_acc=0.859
# Epoch: 19/20,    1000/2500 steps,    avg_loss=0.305,    avg_acc=0.875
# Epoch: 19/20,    1200/2500 steps,    avg_loss=0.388,    avg_acc=0.859
#   --> val_loss=0.359,   val_acc=0.86
# Epoch: 19/20,    1400/2500 steps,    avg_loss=0.31,    avg_acc=0.859
# Epoch: 19/20,    1600/2500 steps,    avg_loss=0.248,    avg_acc=0.922
# Epoch: 19/20,    1800/2500 steps,    avg_loss=0.414,    avg_acc=0.812
#   --> val_loss=0.359,   val_acc=0.862
# Epoch: 19/20,    2000/2500 steps,    avg_loss=0.312,    avg_acc=0.859
# Epoch: 19/20,    2200/2500 steps,    avg_loss=0.326,    avg_acc=0.875
# Epoch: 19/20,    2400/2500 steps,    avg_loss=0.304,    avg_acc=0.891
#   --> val_loss=0.347,   val_acc=0.868
# Epoch: 20/20,    100/2500 steps,    avg_loss=0.397,    avg_acc=0.812
# Epoch: 20/20,    300/2500 steps,    avg_loss=0.223,    avg_acc=0.938
# Epoch: 20/20,    500/2500 steps,    avg_loss=0.3,    avg_acc=0.875
#   --> val_loss=0.35,   val_acc=0.865
# Epoch: 20/20,    700/2500 steps,    avg_loss=0.302,    avg_acc=0.891
# Epoch: 20/20,    900/2500 steps,    avg_loss=0.284,    avg_acc=0.906
# Epoch: 20/20,    1100/2500 steps,    avg_loss=0.423,    avg_acc=0.781
#   --> val_loss=0.353,   val_acc=0.864
# Epoch: 20/20,    1300/2500 steps,    avg_loss=0.334,    avg_acc=0.891
# Epoch: 20/20,    1500/2500 steps,    avg_loss=0.218,    avg_acc=0.938
# Epoch: 20/20,    1700/2500 steps,    avg_loss=0.273,    avg_acc=0.859
#   --> val_loss=0.36,   val_acc=0.862
# Epoch: 20/20,    1900/2500 steps,    avg_loss=0.208,    avg_acc=0.938
# Epoch: 20/20,    2100/2500 steps,    avg_loss=0.218,    avg_acc=0.922
# Epoch: 20/20,    2300/2500 steps,    avg_loss=0.292,    avg_acc=0.891
#   --> val_loss=0.348,   val_acc=0.866
# Epoch: 20/20,    2500/2500 steps,    avg_loss=0.383,    avg_acc=0.844

# %%
# test the final model

test_loss, test_acc = test()
history['test_loss'] = test_loss
history['test_acc'] = test_acc
print(f'test_loss: {round(test_loss, 4)}')
print(f'test_acc: {round(test_acc, 4)}')
# Out:
# test_loss: 0.3446
# test_acc: 0.8663

# %%
# save the final model

if hparams['save_model']:
    model.save_weights(
        file_path=hparams['save_model_file_path'],
        training_hparams=hparams,
    )
    print('model saved!')
# Out:
# model saved!

# %% [markdown]
# ## 6) Plot training results

# %%
def moving_average(data, m):
    avg_data = []
    for i in range(len(data) - m):
        avg_data.append(np.mean(data[i:i+m]))
    return avg_data

# %%
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

moving = 50

max_val_x = len(history['val_loss']) * hparams['validation_every'] 
val_x_range = range(0, max_val_x, hparams['validation_every'])

avg_loss = moving_average(history['loss'], m=moving)

ax0.plot(range(len(avg_loss)), avg_loss, label='training loss')
ax0.plot(val_x_range, history['val_loss'], label='validation loss')
ax0.legend()
ax0.set_xlabel('updates')
ax0.set_ylabel('loss')
ax0.set_title('Training and Validation Losses')

avg_acc = moving_average(history['acc'], m=moving)
ax1.plot(range(len(avg_acc)), avg_acc, label='training acc')
ax1.plot(val_x_range, history['val_acc'], label='validation acc')
ax1.legend()
ax1.set_xlabel('updates')
ax1.set_ylabel('acc')
ax1.set_title('Training and Validation Accuracies')
ax1.axhline(y=1, linestyle='--', alpha=0.3, color='black')
ax1.set_ylim(-0.1, 1.1)
# Out:
# (-0.1, 1.1)
