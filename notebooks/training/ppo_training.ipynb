# %% [markdown]
# # Training a PPO Agent

# %% [markdown]
# **GOAL:** To train a _PPO Agent_ to play Connect4. This is the second part of our training pipeline (the second part also includes other RL algorithms):
#   - **Part 1) Supervised Learning**
#     - refer to *'src/train/part1_supervised_learning.ipynb'*.
#     - RESULT: a pre-trained network with basic knowledge of the game
#   - **Part 2) Reinforcement Learning**
#     - In this case: Proximal Policy Optimization
#     - **TRANFER LEARNING FROM PART 1:**
#       - Load the pre-trained weights from Part 1
#       - Freeze the convolutional block (*feature extractor*, it is not trained here)
#       - Train the rest of Fully Connected to estimate the optimal policy and the state values.
# <br>
#
# **METHOD:**
#    - We used an *Experience Buffer* to store different episodes
#        - capacity = 2000
#        - exponent for reward backpropagation = 3
#        - for more details on the implementation refer to '*src/data/replay_memory.py*'
#    - The network architecture we used is defined in '*src/models/architectures/cnet128.json*'
#    - We applied *transfer learning* to use the knowledge learned in '*src/train/part1_supervised_learning.ipynb*'
#        - 1. load the network weights from '*src/models/saved_models/network_128.pt*'
#        - 2. freeze the convolutional block (*feature extractor*)
#        - 3. train the fully-connected layers to learn the policy and the state values
#    - There is an '*old agent*' that is an older and stable version of the agent. It is updated when:
#        - the agent achieve a new best win rate against the 1-StepLA Agent
#    - When the performance of the current network decreases significantly, the latest changes are undone and it goes back to the most recent *old weights*
# <br>
#
# **TRAINING:**
#    - We trained for 100k time steps (aprox 320 iterations)
#    - The learning hyperparameters are:
#        - buffer capacity = 2000
#        - ppo epochs = 5
#        - c1 = 0.75
#        - c2 = 0.04
#        - learning rate = 1e-4
#        - batch size = 32
#        - weight decay (L2 regularization) = 5e-5
#        - discount factor (gamma) = 0.95
#        - loss function (critic) = Smooth L1
#    - Every 1000 updates, the PPO agent competes against:
#        - vs the Random Agent
#        - vs the older network
#        - vs the 1-Step Lookahead Agent
# <br>
#
# **PPO RESULTS:**
#    - Our best PPO gent beats the 1-Step LookAhead Agent **≈84%** of the time
#    - The weights of the model are saved in '*src/models/saved_models/best_ppo.pt*'
#    - The training hyperaparameters are saved in '*src/models/saved_models/best_ppo_hparams.json*'
#    - Plots of the training losses
#    - Plots of the average game length in self-play games
#    - Plots of the evolution of the win rate vs 1StepLA

# %% [markdown]
# ## 1) Imports

# %%
import sys
import os
import math
import copy
from datetime import datetime
from pathlib import Path

import torch
import torch.nn as nn
import numpy as np
from torchsummary import summary
import matplotlib.pyplot as plt
from torch.utils.data.sampler import BatchSampler, SubsetRandomSampler

# Auto-detect project root
root = Path(os.getcwd()).parents[1]
if str(root) not in sys.path:
    sys.path.append(str(root))
    print(f"Added {root} to sys.path")
# Out:
# Added /home/luiscunha/AR to sys.path

# %%
from connect4_rl.agents.baselines.random_agent import RandomAgent
from connect4_rl.agents.baselines.n_step_lookahead_agent import NStepLookaheadAgent
from connect4_rl.agents.training.custom_net import CustomNetwork
from connect4_rl.agents.training.custom_pg_agent import PGAgent
from connect4_rl.envs.connect_four import ConnectFourEnv, get_illegal_actions
from connect4_rl.utils.replay_memory import ReplayMemory
from connect4_rl.experiments.competition import competition

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
timestamp =datetime.now().strftime("%d%m_%H%M")
print(f"'{timestamp}'")
# Out:
# '0905_1809'

# %%
SAVE_MODELS = True  # if False, it is debug mode

# %% [markdown]
# ## 2) Hyper parameters

# %%
hparams = {
    # environment, data, memory
    'buffer_capacity': 2000,
    'reward_backprop_exponent': 3,
    
    # agent properties and model architecture
    'avg_symmetric_probs': True,
    'model_arch_path': '../../models/novo/architectures/cnet128.json',
    'pretrained_model_weights': '../../models/novo/weights/supervised_cnet128.pt',
    'freeze_conv_block': True,
    
    # Information displayed while training
    'loss_log_every': 1,
    'comp_every': 5,
    'vs_1StepLA_win_rate_decrease_to_undo_updates': 0.08,
    'moving_avg': 100,
        
    # PPO hyperparameters
    'num_iterations': 320,
    'clip_param': 0.2,
    'ppo_epoch': 5,
    'c1': 0.75,
    'c2': 0.04,
    
    # Training loop params
    'batch_size': 32,
    'gamma' : 0.95,
    'weight_decay': 5e-5,
    'lr': 1e-4
}

# %% [markdown]
# ## 3) PPO Agent

# %%
def load_state_dict(from_: nn.Module, to_: nn.Module) -> None:
    """
    Copies the weights from the module 'from_' to the module 'to_'
    Loading the state_dict from a module does not keep the
    convolutional_block frozen, so it has to be done manually.
    """

    to_.load_state_dict(from_.state_dict())
    if hparams['freeze_conv_block']:
        for param in to_.conv_block.parameters():
            param.requires_grad = False

            

def create_model() -> nn.Module:
    """
    Create a PPO network following the architecture in 'model_arch_file',
    and initializing the network with the weights stored in 'load_weights_path'. 
    """

    ppo_net = CustomNetwork.from_architecture(
        file_path=hparams['model_arch_path']
    ).to(device)
    
    ppo_net.load_weights(hparams['pretrained_model_weights'])
    
    for param in ppo_net.conv_block.parameters():
        param.requires_grad = False
    
    return ppo_net


def create_agent():
    """
    Create a new PPO Agent
    """

    model_ = create_model()
    agent_ = PGAgent(
        model=model_,
        stochastic_mode=True,
        avg_symmetric_probs=hparams['avg_symmetric_probs'],
        name='PPO Agent'
    )
    return agent_

# %%
ppo_agent = create_agent()

print("model device is cuda?", next(ppo_agent.model.parameters()).is_cuda)
print()
print(summary(ppo_agent.model, input_size=ppo_agent.model.input_shape))
# Out:
# model device is cuda? True
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 128, 3, 4]           4,224
#               ReLU-2            [-1, 128, 3, 4]               0
#             Conv2d-3            [-1, 128, 2, 3]          65,664
#               ReLU-4            [-1, 128, 2, 3]               0
#             Linear-5                  [-1, 128]          98,432
#               ReLU-6                  [-1, 128]               0
#             Linear-7                  [-1, 128]          16,512
#               ReLU-8                  [-1, 128]               0
#             Linear-9                    [-1, 7]             903
#            Linear-10                  [-1, 128]          16,512
#              ReLU-11                  [-1, 128]               0
#            Linear-12                    [-1, 1]             129
# ================================================================
# Total params: 202,376
# Trainable params: 132,488
# Non-trainable params: 69,888
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.04
# Params size (MB): 0.77
# Estimated Total Size (MB): 0.81
# ----------------------------------------------------------------
# None
# /home/luiscunha/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,

# %%
old_ppo_agent = create_agent()
load_state_dict(from_=ppo_agent.model, to_=old_ppo_agent.model)
old_ppo_agent.model.eval()
# Out:
# CustomNetwork(
#   (conv_block): Sequential(
#     (0): Conv2d(2, 128, kernel_size=(4, 4), stride=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(128, 128, kernel_size=(2, 2), stride=(1, 1))
#     (3): ReLU()
#   )
#   (fc_block): Sequential(
#     (0): Linear(in_features=768, out_features=128, bias=True)
#     (1): ReLU()
#   )
#   (first_head): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=7, bias=True)
#   )
#   (second_head): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
agent_name = ppo_agent.name.replace(' ', '_')
save_best_vs_1StepLA_file = f'{agent_name}_'+'{win_rate}_vs_1StepLA_'+f'{timestamp}.pt'

print('"' + save_best_vs_1StepLA_file + '"')
# Out:
# "PPO_Agent_{win_rate}_vs_1StepLA_0905_1809.pt"

# %% [markdown]
# ## 4) Experience Buffer

# %%
buffer = ReplayMemory(
    capacity=hparams['buffer_capacity'],
    reward_backprop_exponent=hparams['reward_backprop_exponent']
)

# %% [markdown]
# ## 5) Prepare the training lopp

# %%
critic_loss_func = nn.SmoothL1Loss()

optimizer = torch.optim.Adam(
    params=ppo_agent.model.parameters(), 
    lr=hparams['lr'],
    weight_decay=hparams['weight_decay']
)

# %%
def compute_avg_target_value(policy_: nn.Module, states_: torch.tensor) -> torch.tensor:
    """
    Compute the value of the given states.
    NOTE: output does not contain gradient, it is part of the target
    It takes advantage of the board symmetry.
    """

    with torch.no_grad():
        _, v = policy_(states_)

    sym_states = torch.flip(states_, dims=[-1])
    with torch.no_grad():
        _, sym_v = policy_(sym_states)
    
    avg_v = (v + sym_v) / 2
    return avg_v

# %%
def training_step(policy_, 
                  optimizer_,
                  buffer_, 
                  hparams_, 
                  critic_loss_func_):

    gamma = hparams_['gamma']
    ppo_epoch = hparams_['ppo_epoch']
    batch_size = hparams_['batch_size']
    clip_param = hparams_['clip_param']
    c1 = hparams_['c1']
    c2 = hparams_['c2']  # entropy coefficient
    
    policy_.train()
    
    data = copy.deepcopy(buffer_.all_data())
    transitions = buffer_.Transition(*zip(*data))

    tuple_state_batch = tuple([policy_.obs_to_model_input(obs=s)
                               for s in transitions.state])
    tuple_next_state_batch = tuple([policy_.obs_to_model_input(obs=s_)
                                    for s_ in transitions.next_state])
    
    state_batch = torch.cat(tuple_state_batch).float().to(device)
    next_state_batch = torch.cat(tuple_next_state_batch).float().to(device)
    action_batch = torch.tensor(transitions.action, dtype=torch.long, device=device)
    reward_batch = torch.tensor(transitions.reward, dtype=torch.float, device=device).view(-1,1)
    not_done_mask = 1 - torch.tensor(transitions.done, device=device, dtype=torch.int).view(-1,1)

    
    old_a_logp = torch.tensor(transitions.log_prob, 
                              dtype=torch.float,
                              device=device).view(-1, 1)

    with torch.no_grad():
        target_v = reward_batch - gamma*not_done_mask*compute_avg_target_value(policy_, next_state_batch)
        adv = target_v - compute_avg_target_value(policy_, state_batch)
        
    total_losses, policy_losses, value_losses, entropies, ratios = [], [], [], [], []

    for epoch in range(ppo_epoch):
        for index in BatchSampler(SubsetRandomSampler(range(buffer_.capacity)), batch_size, False):
            logits, _ = policy_(state_batch[index])
            dist = torch.distributions.Categorical(logits=logits)
            entropy = dist.entropy()
            
            a_logp = dist.log_prob(action_batch[index]).unsqueeze(-1)
            a_logp_old = old_a_logp[index]

            # Compute ratio: pi/pi_old = e^(ln pi - ln pi_old)
            ratio = torch.exp(a_logp - a_logp_old)

            surr1 = ratio * adv[index]

            surr2 = torch.clamp(ratio, 1.0-clip_param, 1.0+clip_param) * adv[index]

            policy_loss = torch.min(surr1, surr2).mean()
            value_loss = critic_loss_func_(policy_(state_batch[index])[1], target_v[index])
            entropy = entropy.mean()

            loss = - policy_loss + c1*value_loss - c2*entropy

            optimizer_.zero_grad()
            loss.backward()
            optimizer_.step()
            
            total_losses.append(loss.item())
            policy_losses.append(-policy_loss.item())
            value_losses.append(value_loss.item())
            entropies.append(entropy.item())
            ratios.append(ratio.mean().item())

    return total_losses, policy_losses, value_losses, entropies, ratios

# %% [markdown]
# ## 6) Training loop

# %%
history = {'total_losses': [], 'policy_losses': [], 'value_losses': [], 
           'entropies': [], 'ratios': [],
           'vs_random_win_rate': [], 'vs_random_avg_game_len': [],
           'vs_1StepLA_win_rate': [], 'vs_1StepLA_avg_game_len': [],
           'vs_old_self_win_rate': [], 'vs_old_self_avg_game_len': [],
           'comp_every': hparams['comp_every'], 'comp_n_episodes': 100,
          }

vs_1StepLA_best_win_rate = 0.5

if not os.path.exists('checkpoints'):
    os.makedirs('checkpoints')

env = ConnectFourEnv()
comp_env = ConnectFourEnv()

random_opponent = RandomAgent()
oneStepLA = NStepLookaheadAgent(n=1, prefer_central_columns=True)

eps_ = np.finfo(np.float32).eps.item()
n_updates = 0
for i_iter in range(hparams['num_iterations']):
    
    buffer.reset()
    ppo_agent.model.train()
    
    while len(buffer) != buffer.capacity:
        buffer.push_self_play_episode_transitions(
            agent=ppo_agent,
            env=env,
            init_random_obs=True,
            push_symmetric=True,
            exploration_rate=0.10,
        )
    
    total_losses, policy_loss, value_loss, avg_entropy, ratios = training_step(
        policy_=ppo_agent.model, 
        optimizer_=optimizer, 
        buffer_=buffer, 
        hparams_=hparams,
        critic_loss_func_=critic_loss_func,
    )
    n_updates += len(total_losses)

    history['total_losses'].extend(total_losses)
    history['policy_losses'].extend(policy_loss)
    history['value_losses'].extend(value_loss)
    history['entropies'].extend(avg_entropy)
    history['ratios'].extend(ratios)
    
    if (i_iter+1) % hparams['loss_log_every'] == 0:
        last_total_loss_vals = history['total_losses'][-hparams['moving_avg']:]
        last_policy_loss_vals = history['policy_losses'][-hparams['moving_avg']:]
        last_value_loss_vals = history['value_losses'][-hparams['moving_avg']:]
        last_avg_entropy_vals = history['entropies'][-hparams['moving_avg']:]
        last_ratio_vals = history['ratios'][-hparams['moving_avg']:]
        print(f"Iter: {i_iter+1}/{hparams['num_iterations']}   " +
              f"update: {n_updates}   "
              f"Loss: {round(np.mean(last_total_loss_vals), 4)}   " +
              f"P_Loss: {round(np.mean(last_policy_loss_vals), 4)}   " +
              f"V_Loss: {round(np.mean(last_value_loss_vals), 4)}   " +
              f"S: {round(np.mean(last_avg_entropy_vals), 3)}   ")
    
    # compete against the opponents to measure the performance
    if (i_iter+1) % hparams['comp_every'] == 0:
        # compete against the Random Agent
        ppo_agent.model.eval()
        with torch.no_grad():
            res1, o1 = competition(
                env=comp_env, 
                agent1=ppo_agent, 
                agent2=random_opponent,
                progress_bar=False,
            )
        win_rate_rand = round(res1['win_rate1'], 3)
        print(f"    {win_rate_rand} vs. RAND" +
              f"    avg_len={round(res1['avg_game_len'], 2)}")
        history['vs_random_win_rate'].append(win_rate_rand)
        history['vs_random_avg_game_len'].append(res1['avg_game_len'])

        # compete againts the old (stable) version of the network
        old_ppo_agent.model.eval()
        with torch.no_grad():
            res2, o2 = competition(
                env=comp_env, 
                agent1=ppo_agent, 
                agent2=old_ppo_agent,
                progress_bar=False,
            )
        win_rate_self = round(res2['win_rate1'], 3)
        print(f"    {win_rate_self} vs. SELF" +
              f"    avg_len={round(res2['avg_game_len'], 2)}")
        history['vs_old_self_win_rate'].append(win_rate_self)
        history['vs_old_self_avg_game_len'].append(res2['avg_game_len'])

        # compete against the Professional Player
        with torch.no_grad():
            res3, o3 = competition(
                env=comp_env, 
                agent1=ppo_agent,
                agent2=oneStepLA,
                progress_bar=False,
            )
        win_rate_1StepLA = round(res3['win_rate1'], 3)
        print(f"    {win_rate_1StepLA} vs. 1StepLA" +
              f"    avg_len={round(res3['avg_game_len'], 2)}")
        history['vs_1StepLA_win_rate'].append(win_rate_1StepLA)
        history['vs_1StepLA_avg_game_len'].append(res3['avg_game_len'])

        if win_rate_1StepLA > vs_1StepLA_best_win_rate:
            vs_1StepLA_best_win_rate = win_rate_1StepLA
            load_state_dict(from_=ppo_agent.model, to_=old_ppo_agent.model)
            old_ppo_agent.model.eval()
            if SAVE_MODELS:
                file_name = (
                    f"checkpoints/" + save_best_vs_1StepLA_file.format(win_rate=int(win_rate_1StepLA*100))
                )
                ppo_agent.model.save_weights(
                    file_path=file_name,
                    training_hparams=hparams,
                )
                print(f"        new best {file_name} is saved!!!")
        elif win_rate_1StepLA <= vs_1StepLA_best_win_rate-hparams['vs_1StepLA_win_rate_decrease_to_undo_updates']:
            load_state_dict(from_=old_ppo_agent.model, to_=ppo_agent.model)
            print("        undoing last updates...")
# Out:
# Iter: 1/320   update: 315   Loss: 0.3718   P_Loss: 0.3053   V_Loss: 0.1075   S: 0.354
# Iter: 2/320   update: 630   Loss: -0.1126   P_Loss: -0.1651   V_Loss: 0.0914   S: 0.403
# Iter: 3/320   update: 945   Loss: 0.1944   P_Loss: 0.1458   V_Loss: 0.0863   S: 0.402
# Iter: 4/320   update: 1260   Loss: -0.0436   P_Loss: -0.0954   V_Loss: 0.0924   S: 0.436
# Iter: 5/320   update: 1575   Loss: 0.1438   P_Loss: 0.1051   V_Loss: 0.0754   S: 0.446
#     0.99 vs. RAND    avg_len=7.79
#     0.52 vs. SELF    avg_len=11.72
#     0.52 vs. 1StepLA    avg_len=10.58
#         new best checkpoints/PPO_Agent_52_vs_1StepLA_0905_1809.pt is saved!!!
# Iter: 6/320   update: 1890   Loss: 0.0806   P_Loss: 0.04   V_Loss: 0.0781   S: 0.45
# Iter: 7/320   update: 2205   Loss: 0.063   P_Loss: 0.0204   V_Loss: 0.0815   S: 0.463
# Iter: 8/320   update: 2520   Loss: -0.0265   P_Loss: -0.0713   V_Loss: 0.0855   S: 0.482
# Iter: 9/320   update: 2835   Loss: 0.0837   P_Loss: 0.0471   V_Loss: 0.0744   S: 0.481
# Iter: 10/320   update: 3150   Loss: 0.061   P_Loss: 0.0063   V_Loss: 0.0988   S: 0.484
#     1.0 vs. RAND    avg_len=8.12
#     0.5 vs. SELF    avg_len=12.04
#     0.5 vs. 1StepLA    avg_len=11.08
# Iter: 11/320   update: 3465   Loss: 0.1965   P_Loss: 0.1468   V_Loss: 0.0906   S: 0.455
# Iter: 12/320   update: 3780   Loss: -0.1199   P_Loss: -0.1703   V_Loss: 0.0919   S: 0.464
# Iter: 13/320   update: 4095   Loss: 0.2232   P_Loss: 0.1761   V_Loss: 0.0871   S: 0.454
# Iter: 14/320   update: 4410   Loss: -0.0303   P_Loss: -0.0776   V_Loss: 0.0876   S: 0.46
# Iter: 15/320   update: 4725   Loss: 0.1578   P_Loss: 0.1068   V_Loss: 0.093   S: 0.469
#     1.0 vs. RAND    avg_len=7.66
#     0.4 vs. SELF    avg_len=12.24
#     0.53 vs. 1StepLA    avg_len=12.4
#         new best checkpoints/PPO_Agent_53_vs_1StepLA_0905_1809.pt is saved!!!
# Iter: 16/320   update: 5040   Loss: 0.0048   P_Loss: -0.0631   V_Loss: 0.1154   S: 0.465
# Iter: 17/320   update: 5355   Loss: 0.1555   P_Loss: 0.0956   V_Loss: 0.1055   S: 0.48
# Iter: 18/320   update: 5670   Loss: 0.0515   P_Loss: 0.0003   V_Loss: 0.0943   S: 0.49
# Iter: 19/320   update: 5985   Loss: 0.0857   P_Loss: 0.041   V_Loss: 0.085   S: 0.477
# Iter: 20/320   update: 6300   Loss: 0.0129   P_Loss: -0.0304   V_Loss: 0.0847   S: 0.506
#     1.0 vs. RAND    avg_len=7.58
#     0.51 vs. SELF    avg_len=12.11
#     0.54 vs. 1StepLA    avg_len=11.16
#         new best checkpoints/PPO_Agent_54_vs_1StepLA_0905_1809.pt is saved!!!
# Iter: 21/320   update: 6615   Loss: 0.1125   P_Loss: 0.0567   V_Loss: 0.1008   S: 0.495
# Iter: 22/320   update: 6930   Loss: 0.0449   P_Loss: 0.003   V_Loss: 0.0833   S: 0.517
# Iter: 23/320   update: 7245   Loss: 0.1116   P_Loss: 0.0492   V_Loss: 0.1107   S: 0.516
# Iter: 24/320   update: 7560   Loss: 0.008   P_Loss: -0.0465   V_Loss: 0.1011   S: 0.532
# Iter: 25/320   update: 7875   Loss: 0.1806   P_Loss: 0.1342   V_Loss: 0.0898   S: 0.524
#     1.0 vs. RAND    avg_len=8.54
#     0.39 vs. SELF    avg_len=12.25
#     0.51 vs. 1StepLA    avg_len=11.47
# Iter: 26/320   update: 8190   Loss: -0.0515   P_Loss: -0.1093   V_Loss: 0.1042   S: 0.509
# Iter: 27/320   update: 8505   Loss: 0.2304   P_Loss: 0.1665   V_Loss: 0.109   S: 0.446
# Iter: 28/320   update: 8820   Loss: -0.1254   P_Loss: -0.1775   V_Loss: 0.0965   S: 0.506
# Iter: 29/320   update: 9135   Loss: 0.2893   P_Loss: 0.2328   V_Loss: 0.1009   S: 0.479
# Iter: 30/320   update: 9450   Loss: -0.0816   P_Loss: -0.1328   V_Loss: 0.0962   S: 0.523
#     0.99 vs. RAND    avg_len=8.23
#     0.5 vs. SELF    avg_len=12.42
#     0.55 vs. 1StepLA    avg_len=12.47
#         new best checkpoints/PPO_Agent_55_vs_1StepLA_0905_1809.pt is saved!!!
# Iter: 31/320   update: 9765   Loss: 0.2741   P_Loss: 0.2183   V_Loss: 0.1007   S: 0.494
# Iter: 32/320   update: 10080   Loss: -0.2114   P_Loss: -0.2695   V_Loss: 0.1057   S: 0.528
# Iter: 33/320   update: 10395   Loss: 0.3064   P_Loss: 0.2577   V_Loss: 0.0907   S: 0.486
# Iter: 34/320   update: 10710   Loss: -0.0672   P_Loss: -0.128   V_Loss: 0.1069   S: 0.485
# Iter: 35/320   update: 11025   Loss: 0.186   P_Loss: 0.1308   V_Loss: 0.1006   S: 0.507
#     0.99 vs. RAND    avg_len=8.43
#     0.47 vs. SELF    avg_len=12.73
#     0.56 vs. 1StepLA    avg_len=12.56
#         new best checkpoints/PPO_Agent_56_vs_1StepLA_0905_1809.pt is saved!!!
# Iter: 36/320   update: 11340   Loss: 0.011   P_Loss: -0.0302   V_Loss: 0.082   S: 0.507
# Iter: 37/320   update: 11655   Loss: 0.2821   P_Loss: 0.225   V_Loss: 0.1015   S: 0.477
# Iter: 38/320   update: 11970   Loss: 0.011   P_Loss: -0.0488   V_Loss: 0.106   S: 0.49
# Iter: 39/320   update: 12285   Loss: 0.1872   P_Loss: 0.1372   V_Loss: 0.0909   S: 0.454
# Iter: 40/320   update: 12600   Loss: -0.0157   P_Loss: -0.0707   V_Loss: 0.0988   S: 0.478
#     1.0 vs. RAND    avg_len=8.1
#     0.58 vs. SELF    avg_len=13.85
#     0.6 vs. 1StepLA    avg_len=12.38
#         new best checkpoints/PPO_Agent_60_vs_1StepLA_0905_1809.pt is saved!!!
# Iter: 41/320   update: 12915   Loss: 0.0921   P_Loss: 0.0405   V_Loss: 0.0935   S: 0.462
# Iter: 42/320   update: 13230   Loss: 0.0341   P_Loss: -0.022   V_Loss: 0.0998   S: 0.467
# Iter: 43/320   update: 13545   Loss: 0.076   P_Loss: 0.0276   V_Loss: 0.0908   S: 0.491
# Iter: 44/320   update: 13860   Loss: 0.1537   P_Loss: 0.1065   V_Loss: 0.088   S: 0.469
# Iter: 45/320   update: 14175   Loss: -0.055   P_Loss: -0.1169   V_Loss: 0.1072   S: 0.461
#     1.0 vs. RAND    avg_len=8.16
#     0.48 vs. SELF    avg_len=12.9
#     0.58 vs. 1StepLA    avg_len=12.38
# Iter: 46/320   update: 14490   Loss: 0.3287   P_Loss: 0.2696   V_Loss: 0.1041   S: 0.474
# Iter: 47/320   update: 14805   Loss: -0.0924   P_Loss: -0.1423   V_Loss: 0.092   S: 0.476
# Iter: 48/320   update: 15120   Loss: 0.3623   P_Loss: 0.3077   V_Loss: 0.0977   S: 0.467
# Iter: 49/320   update: 15435   Loss: -0.0873   P_Loss: -0.1425   V_Loss: 0.0987   S: 0.472
# Iter: 50/320   update: 15750   Loss: 0.2525   P_Loss: 0.1972   V_Loss: 0.099   S: 0.474
#     0.99 vs. RAND    avg_len=8.59
#     0.49 vs. SELF    avg_len=14.17
#     0.62 vs. 1StepLA    avg_len=13.16
#         new best checkpoints/PPO_Agent_62_vs_1StepLA_0905_1809.pt is saved!!!
# Iter: 51/320   update: 16065   Loss: -0.0817   P_Loss: -0.1319   V_Loss: 0.0907   S: 0.447
# Iter: 52/320   update: 16380   Loss: 0.216   P_Loss: 0.161   V_Loss: 0.0981   S: 0.464
# Iter: 53/320   update: 16695   Loss: 0.0374   P_Loss: -0.0237   V_Loss: 0.1059   S: 0.456
# Iter: 54/320   update: 17010   Loss: 0.1877   P_Loss: 0.1333   V_Loss: 0.0954   S: 0.429
# Iter: 55/320   update: 17325   Loss: 0.1332   P_Loss: 0.0737   V_Loss: 0.1025   S: 0.435
#     1.0 vs. RAND    avg_len=8.66
#     0.5 vs. SELF    avg_len=14.76
#     0.59 vs. 1StepLA    avg_len=13.41
# Iter: 56/320   update: 17640   Loss: -0.0259   P_Loss: -0.0811   V_Loss: 0.0953   S: 0.407
# Iter: 57/320   update: 17955   Loss: 0.2224   P_Loss: 0.1711   V_Loss: 0.0902   S: 0.41
# Iter: 58/320   update: 18270   Loss: 0.139   P_Loss: 0.0727   V_Loss: 0.1105   S: 0.415
# Iter: 59/320   update: 18585   Loss: 0.0341   P_Loss: -0.0163   V_Loss: 0.0917   S: 0.458
# Iter: 60/320   update: 18900   Loss: 0.2105   P_Loss: 0.1529   V_Loss: 0.1007   S: 0.448
#     0.99 vs. RAND    avg_len=8.93
#     0.48 vs. SELF    avg_len=14.16
#     0.6 vs. 1StepLA    avg_len=13.22
# Iter: 61/320   update: 19215   Loss: -0.098   P_Loss: -0.1441   V_Loss: 0.0848   S: 0.438
# Iter: 62/320   update: 19530   Loss: 0.3069   P_Loss: 0.2508   V_Loss: 0.0995   S: 0.462
# Iter: 63/320   update: 19845   Loss: 0.0587   P_Loss: -0.0014   V_Loss: 0.1037   S: 0.443
# Iter: 64/320   update: 20160   Loss: 0.1875   P_Loss: 0.1226   V_Loss: 0.1091   S: 0.425
# Iter: 65/320   update: 20475   Loss: -0.0252   P_Loss: -0.0754   V_Loss: 0.0911   S: 0.451
#     0.99 vs. RAND    avg_len=8.83
#     0.56 vs. SELF    avg_len=15.7
#     0.53 vs. 1StepLA    avg_len=12.31
#         undoing last updates...
# Iter: 66/320   update: 20790   Loss: -0.0369   P_Loss: -0.0887   V_Loss: 0.095   S: 0.486
# Iter: 67/320   update: 21105   Loss: 0.3108   P_Loss: 0.2634   V_Loss: 0.0892   S: 0.49
# Iter: 68/320   update: 21420   Loss: -0.0261   P_Loss: -0.0945   V_Loss: 0.1153   S: 0.451
# Iter: 69/320   update: 21735   Loss: 0.1258   P_Loss: 0.067   V_Loss: 0.1008   S: 0.422
# Iter: 70/320   update: 22050   Loss: 0.2782   P_Loss: 0.2108   V_Loss: 0.1125   S: 0.425
#     1.0 vs. RAND    avg_len=8.38
#     0.5 vs. SELF    avg_len=13.8
#     0.58 vs. 1StepLA    avg_len=12.76
# Iter: 71/320   update: 22365   Loss: -0.0545   P_Loss: -0.1153   V_Loss: 0.1031   S: 0.414
# Iter: 72/320   update: 22680   Loss: 0.2481   P_Loss: 0.1939   V_Loss: 0.0956   S: 0.437
# Iter: 73/320   update: 22995   Loss: 0.0685   P_Loss: 0.0093   V_Loss: 0.1027   S: 0.446
# Iter: 74/320   update: 23310   Loss: 0.0451   P_Loss: 0.0015   V_Loss: 0.0845   S: 0.494
# Iter: 75/320   update: 23625   Loss: 0.1578   P_Loss: 0.1037   V_Loss: 0.0944   S: 0.417
#     0.99 vs. RAND    avg_len=8.19
#     0.54 vs. SELF    avg_len=14.88
#     0.59 vs. 1StepLA    avg_len=13.37
# Iter: 76/320   update: 23940   Loss: 0.0762   P_Loss: 0.0307   V_Loss: 0.0844   S: 0.444
# Iter: 77/320   update: 24255   Loss: 0.1792   P_Loss: 0.1175   V_Loss: 0.1047   S: 0.42
# Iter: 78/320   update: 24570   Loss: 0.0578   P_Loss: -0.0021   V_Loss: 0.1035   S: 0.442
# Iter: 79/320   update: 24885   Loss: 0.1395   P_Loss: 0.0869   V_Loss: 0.0938   S: 0.443
# Iter: 80/320   update: 25200   Loss: 0.1405   P_Loss: 0.066   V_Loss: 0.1217   S: 0.42
#     1.0 vs. RAND    avg_len=8.2
#     0.51 vs. SELF    avg_len=14.97
#     0.6 vs. 1StepLA    avg_len=12.9
# Iter: 81/320   update: 25515   Loss: 0.0753   P_Loss: 0.0268   V_Loss: 0.09   S: 0.476
# Iter: 82/320   update: 25830   Loss: 0.2649   P_Loss: 0.2162   V_Loss: 0.0888   S: 0.448
# Iter: 83/320   update: 26145   Loss: 0.0401   P_Loss: -0.0136   V_Loss: 0.0965   S: 0.468
# Iter: 84/320   update: 26460   Loss: 0.2135   P_Loss: 0.1408   V_Loss: 0.1207   S: 0.444
# Iter: 85/320   update: 26775   Loss: 0.0749   P_Loss: 0.0153   V_Loss: 0.1011   S: 0.405
#     0.98 vs. RAND    avg_len=8.54
#     0.52 vs. SELF    avg_len=15.0
#     0.58 vs. 1StepLA    avg_len=12.14
# Iter: 86/320   update: 27090   Loss: 0.0737   P_Loss: 0.017   V_Loss: 0.0984   S: 0.425
# Iter: 87/320   update: 27405   Loss: 0.1845   P_Loss: 0.1302   V_Loss: 0.0936   S: 0.398
# Iter: 88/320   update: 27720   Loss: 0.0952   P_Loss: 0.0424   V_Loss: 0.0872   S: 0.315
# Iter: 89/320   update: 28035   Loss: 0.2236   P_Loss: 0.1796   V_Loss: 0.0777   S: 0.356
# Iter: 90/320   update: 28350   Loss: 0.0061   P_Loss: -0.0468   V_Loss: 0.0909   S: 0.382
#     1.0 vs. RAND    avg_len=8.6
#     0.51 vs. SELF    avg_len=14.23
#     0.51 vs. 1StepLA    avg_len=11.77
#         undoing last updates...
# Iter: 91/320   update: 28665   Loss: -0.0584   P_Loss: -0.1126   V_Loss: 0.096   S: 0.446
# Iter: 92/320   update: 28980   Loss: 0.2496   P_Loss: 0.197   V_Loss: 0.0946   S: 0.459
# Iter: 93/320   update: 29295   Loss: 0.0177   P_Loss: -0.0436   V_Loss: 0.1058   S: 0.453
# Iter: 94/320   update: 29610   Loss: 0.2474   P_Loss: 0.1902   V_Loss: 0.1007   S: 0.461
# Iter: 95/320   update: 29925   Loss: -0.1247   P_Loss: -0.1849   V_Loss: 0.104   S: 0.447
#     1.0 vs. RAND    avg_len=8.4
#     0.57 vs. SELF    avg_len=15.95
#     0.57 vs. 1StepLA    avg_len=13.41
# Iter: 96/320   update: 30240   Loss: 0.3501   P_Loss: 0.2952   V_Loss: 0.0966   S: 0.439
# Iter: 97/320   update: 30555   Loss: -0.0818   P_Loss: -0.1399   V_Loss: 0.101   S: 0.442
# Iter: 98/320   update: 30870   Loss: 0.2716   P_Loss: 0.2099   V_Loss: 0.1059   S: 0.444
# Iter: 99/320   update: 31185   Loss: 0.0311   P_Loss: -0.0388   V_Loss: 0.1156   S: 0.421
# Iter: 100/320   update: 31500   Loss: 0.1484   P_Loss: 0.0856   V_Loss: 0.1065   S: 0.427
#     0.97 vs. RAND    avg_len=9.13
#     0.53 vs. SELF    avg_len=14.47
#     0.62 vs. 1StepLA    avg_len=13.38
# Iter: 101/320   update: 31815   Loss: 0.1738   P_Loss: 0.1087   V_Loss: 0.1097   S: 0.429
# Iter: 102/320   update: 32130   Loss: 0.092   P_Loss: 0.0493   V_Loss: 0.081   S: 0.451
# Iter: 103/320   update: 32445   Loss: 0.085   P_Loss: 0.035   V_Loss: 0.0916   S: 0.468
# Iter: 104/320   update: 32760   Loss: 0.1255   P_Loss: 0.0693   V_Loss: 0.0992   S: 0.454
# Iter: 105/320   update: 33075   Loss: 0.1414   P_Loss: 0.0806   V_Loss: 0.1058   S: 0.463
#     1.0 vs. RAND    avg_len=8.78
#     0.45 vs. SELF    avg_len=13.93
#     0.67 vs. 1StepLA    avg_len=13.51
#         new best checkpoints/PPO_Agent_67_vs_1StepLA_0905_1809.pt is saved!!!
# Iter: 106/320   update: 33390   Loss: 0.0831   P_Loss: 0.0265   V_Loss: 0.1003   S: 0.467
# Iter: 107/320   update: 33705   Loss: 0.057   P_Loss: 0.0107   V_Loss: 0.0865   S: 0.464
# Iter: 108/320   update: 34020   Loss: 0.0797   P_Loss: 0.0295   V_Loss: 0.0902   S: 0.436
# Iter: 109/320   update: 34335   Loss: 0.177   P_Loss: 0.1074   V_Loss: 0.116   S: 0.434
# Iter: 110/320   update: 34650   Loss: 0.0509   P_Loss: -0.0105   V_Loss: 0.1049   S: 0.432
#     1.0 vs. RAND    avg_len=8.2
#     0.55 vs. SELF    avg_len=16.85
#     0.64 vs. 1StepLA    avg_len=13.22
# Iter: 111/320   update: 34965   Loss: 0.1273   P_Loss: 0.0688   V_Loss: 0.1001   S: 0.413
# Iter: 112/320   update: 35280   Loss: 0.14   P_Loss: 0.0716   V_Loss: 0.1114   S: 0.377
# Iter: 113/320   update: 35595   Loss: 0.1277   P_Loss: 0.0619   V_Loss: 0.1097   S: 0.412
# Iter: 114/320   update: 35910   Loss: 0.1151   P_Loss: 0.0515   V_Loss: 0.1058   S: 0.395
# Iter: 115/320   update: 36225   Loss: 0.0499   P_Loss: -0.0081   V_Loss: 0.0996   S: 0.42
#     0.98 vs. RAND    avg_len=8.8
#     0.56 vs. SELF    avg_len=15.94
#     0.65 vs. 1StepLA    avg_len=13.19
# Iter: 116/320   update: 36540   Loss: 0.1236   P_Loss: 0.0713   V_Loss: 0.0899   S: 0.38
# Iter: 117/320   update: 36855   Loss: 0.1469   P_Loss: 0.0866   V_Loss: 0.1009   S: 0.384
# Iter: 118/320   update: 37170   Loss: 0.1239   P_Loss: 0.0712   V_Loss: 0.093   S: 0.426
# Iter: 119/320   update: 37485   Loss: 0.0546   P_Loss: 0.0081   V_Loss: 0.0826   S: 0.386
# Iter: 120/320   update: 37800   Loss: 0.1669   P_Loss: 0.1107   V_Loss: 0.094   S: 0.357
#     1.0 vs. RAND    avg_len=8.84
#     0.59 vs. SELF    avg_len=15.71
#     0.57 vs. 1StepLA    avg_len=12.37
#         undoing last updates...
# Iter: 121/320   update: 38115   Loss: 0.0816   P_Loss: 0.0356   V_Loss: 0.0854   S: 0.45
# Iter: 122/320   update: 38430   Loss: 0.1808   P_Loss: 0.1081   V_Loss: 0.1197   S: 0.428
# Iter: 123/320   update: 38745   Loss: 0.0615   P_Loss: 0.0172   V_Loss: 0.0846   S: 0.479
# Iter: 124/320   update: 39060   Loss: 0.116   P_Loss: 0.0646   V_Loss: 0.0919   S: 0.438
# Iter: 125/320   update: 39375   Loss: 0.0091   P_Loss: -0.0565   V_Loss: 0.1098   S: 0.42
#     1.0 vs. RAND    avg_len=8.52
#     0.49 vs. SELF    avg_len=13.83
#     0.58 vs. 1StepLA    avg_len=12.72
#         undoing last updates...
# Iter: 126/320   update: 39690   Loss: 0.0685   P_Loss: 0.0162   V_Loss: 0.095   S: 0.476
# Iter: 127/320   update: 40005   Loss: 0.1163   P_Loss: 0.0566   V_Loss: 0.1041   S: 0.458
# Iter: 128/320   update: 40320   Loss: 0.122   P_Loss: 0.0586   V_Loss: 0.1082   S: 0.442
# Iter: 129/320   update: 40635   Loss: 0.2083   P_Loss: 0.1447   V_Loss: 0.1099   S: 0.47
# Iter: 130/320   update: 40950   Loss: 0.0256   P_Loss: -0.0326   V_Loss: 0.1012   S: 0.442
#     0.99 vs. RAND    avg_len=9.15
#     0.51 vs. SELF    avg_len=15.77
#     0.58 vs. 1StepLA    avg_len=13.66
#         undoing last updates...
# Iter: 131/320   update: 41265   Loss: 0.1313   P_Loss: 0.0801   V_Loss: 0.0915   S: 0.436
# Iter: 132/320   update: 41580   Loss: 0.2467   P_Loss: 0.1846   V_Loss: 0.1076   S: 0.466
# Iter: 133/320   update: 41895   Loss: -0.0161   P_Loss: -0.0619   V_Loss: 0.0876   S: 0.498
# Iter: 134/320   update: 42210   Loss: 0.2756   P_Loss: 0.21   V_Loss: 0.1109   S: 0.44
# Iter: 135/320   update: 42525   Loss: 0.0649   P_Loss: 0.0043   V_Loss: 0.1046   S: 0.445
#     1.0 vs. RAND    avg_len=9.56
#     0.49 vs. SELF    avg_len=15.46
#     0.59 vs. 1StepLA    avg_len=13.17
#         undoing last updates...
# Iter: 136/320   update: 42840   Loss: 0.0692   P_Loss: 0.0182   V_Loss: 0.0946   S: 0.499
# Iter: 137/320   update: 43155   Loss: 0.0641   P_Loss: -0.0004   V_Loss: 0.1099   S: 0.45
# Iter: 138/320   update: 43470   Loss: 0.0797   P_Loss: 0.0184   V_Loss: 0.1038   S: 0.411
# Iter: 139/320   update: 43785   Loss: 0.1047   P_Loss: 0.0349   V_Loss: 0.1157   S: 0.423
# Iter: 140/320   update: 44100   Loss: 0.035   P_Loss: -0.0313   V_Loss: 0.1121   S: 0.444
#     1.0 vs. RAND    avg_len=8.14
#     0.54 vs. SELF    avg_len=15.1
#     0.65 vs. 1StepLA    avg_len=12.57
# Iter: 141/320   update: 44415   Loss: 0.2525   P_Loss: 0.1939   V_Loss: 0.1003   S: 0.416
# Iter: 142/320   update: 44730   Loss: 0.0539   P_Loss: -0.0042   V_Loss: 0.0993   S: 0.408
# Iter: 143/320   update: 45045   Loss: 0.1866   P_Loss: 0.1201   V_Loss: 0.1111   S: 0.42
# Iter: 144/320   update: 45360   Loss: 0.1049   P_Loss: 0.0548   V_Loss: 0.0888   S: 0.414
# Iter: 145/320   update: 45675   Loss: 0.1795   P_Loss: 0.1212   V_Loss: 0.0981   S: 0.381
#     0.99 vs. RAND    avg_len=8.81
#     0.56 vs. SELF    avg_len=16.36
#     0.55 vs. 1StepLA    avg_len=13.07
#         undoing last updates...
# Iter: 146/320   update: 45990   Loss: 0.1334   P_Loss: 0.0716   V_Loss: 0.1079   S: 0.479
# Iter: 147/320   update: 46305   Loss: 0.1198   P_Loss: 0.0521   V_Loss: 0.1143   S: 0.449
# Iter: 148/320   update: 46620   Loss: 0.142   P_Loss: 0.0847   V_Loss: 0.1012   S: 0.466
# Iter: 149/320   update: 46935   Loss: 0.0486   P_Loss: -0.0173   V_Loss: 0.112   S: 0.451
# Iter: 150/320   update: 47250   Loss: 0.1702   P_Loss: 0.1134   V_Loss: 0.0998   S: 0.449
#     1.0 vs. RAND    avg_len=8.34
#     0.49 vs. SELF    avg_len=14.55
#     0.55 vs. 1StepLA    avg_len=12.99
#         undoing last updates...
# Iter: 151/320   update: 47565   Loss: 0.0657   P_Loss: 0.0221   V_Loss: 0.084   S: 0.484
# Iter: 152/320   update: 47880   Loss: 0.215   P_Loss: 0.1656   V_Loss: 0.0899   S: 0.452
# Iter: 153/320   update: 48195   Loss: 0.0058   P_Loss: -0.0448   V_Loss: 0.0921   S: 0.461
# Iter: 154/320   update: 48510   Loss: 0.1026   P_Loss: 0.0408   V_Loss: 0.1045   S: 0.412
# Iter: 155/320   update: 48825   Loss: 0.1517   P_Loss: 0.0897   V_Loss: 0.105   S: 0.42
#     0.98 vs. RAND    avg_len=7.92
#     0.5 vs. SELF    avg_len=15.38
#     0.6 vs. 1StepLA    avg_len=12.52
# Iter: 156/320   update: 49140   Loss: 0.1542   P_Loss: 0.1   V_Loss: 0.0958   S: 0.44
# Iter: 157/320   update: 49455   Loss: 0.0449   P_Loss: -0.0137   V_Loss: 0.1024   S: 0.456
# Iter: 158/320   update: 49770   Loss: 0.1128   P_Loss: 0.0587   V_Loss: 0.0949   S: 0.426
# Iter: 159/320   update: 50085   Loss: 0.0598   P_Loss: 0.0126   V_Loss: 0.086   S: 0.433
# Iter: 160/320   update: 50400   Loss: 0.1292   P_Loss: 0.0811   V_Loss: 0.0874   S: 0.434
#     1.0 vs. RAND    avg_len=7.88
#     0.53 vs. SELF    avg_len=14.93
#     0.59 vs. 1StepLA    avg_len=13.09
#         undoing last updates...
# Iter: 161/320   update: 50715   Loss: 0.1481   P_Loss: 0.0802   V_Loss: 0.1145   S: 0.448
# Iter: 162/320   update: 51030   Loss: 0.1058   P_Loss: 0.0432   V_Loss: 0.1086   S: 0.471
# Iter: 163/320   update: 51345   Loss: 0.1713   P_Loss: 0.1088   V_Loss: 0.1079   S: 0.461
# Iter: 164/320   update: 51660   Loss: 0.1295   P_Loss: 0.0677   V_Loss: 0.1052   S: 0.428
# Iter: 165/320   update: 51975   Loss: 0.0022   P_Loss: -0.0451   V_Loss: 0.0858   S: 0.428
#     0.97 vs. RAND    avg_len=9.09
#     0.56 vs. SELF    avg_len=16.16
#     0.65 vs. 1StepLA    avg_len=13.05
# Iter: 166/320   update: 52290   Loss: 0.1999   P_Loss: 0.1382   V_Loss: 0.1051   S: 0.426
# Iter: 167/320   update: 52605   Loss: 0.1152   P_Loss: 0.0461   V_Loss: 0.112   S: 0.372
# Iter: 168/320   update: 52920   Loss: 0.143   P_Loss: 0.0862   V_Loss: 0.098   S: 0.417
# Iter: 169/320   update: 53235   Loss: 0.0345   P_Loss: -0.0266   V_Loss: 0.103   S: 0.405
# Iter: 170/320   update: 53550   Loss: 0.2439   P_Loss: 0.185   V_Loss: 0.1012   S: 0.424
#     0.98 vs. RAND    avg_len=8.62
#     0.52 vs. SELF    avg_len=16.46
#     0.56 vs. 1StepLA    avg_len=12.88
#         undoing last updates...
# Iter: 171/320   update: 53865   Loss: 0.0955   P_Loss: 0.0339   V_Loss: 0.1064   S: 0.455
# Iter: 172/320   update: 54180   Loss: 0.2312   P_Loss: 0.1768   V_Loss: 0.0956   S: 0.432
# Iter: 173/320   update: 54495   Loss: 0.1026   P_Loss: 0.0352   V_Loss: 0.1105   S: 0.388
# Iter: 174/320   update: 54810   Loss: 0.2743   P_Loss: 0.2047   V_Loss: 0.1104   S: 0.33
# Iter: 175/320   update: 55125   Loss: -0.0008   P_Loss: -0.0369   V_Loss: 0.0678   S: 0.367
#     1.0 vs. RAND    avg_len=9.16
#     0.57 vs. SELF    avg_len=15.79
#     0.58 vs. 1StepLA    avg_len=12.38
#         undoing last updates...
# Iter: 176/320   update: 55440   Loss: 0.124   P_Loss: 0.0672   V_Loss: 0.1015   S: 0.484
# Iter: 177/320   update: 55755   Loss: 0.2566   P_Loss: 0.1906   V_Loss: 0.1116   S: 0.443
# Iter: 178/320   update: 56070   Loss: -0.0764   P_Loss: -0.1362   V_Loss: 0.1032   S: 0.443
# Iter: 179/320   update: 56385   Loss: 0.4281   P_Loss: 0.3705   V_Loss: 0.1015   S: 0.463
# Iter: 180/320   update: 56700   Loss: -0.1649   P_Loss: -0.2243   V_Loss: 0.1041   S: 0.466
#     0.98 vs. RAND    avg_len=8.96
#     0.49 vs. SELF    avg_len=17.45
#     0.57 vs. 1StepLA    avg_len=12.41
#         undoing last updates...
# Iter: 181/320   update: 57015   Loss: 0.1041   P_Loss: 0.0385   V_Loss: 0.1124   S: 0.468
# Iter: 182/320   update: 57330   Loss: 0.0812   P_Loss: 0.0226   V_Loss: 0.1025   S: 0.459
# Iter: 183/320   update: 57645   Loss: 0.2785   P_Loss: 0.2154   V_Loss: 0.1072   S: 0.432
# Iter: 184/320   update: 57960   Loss: -0.1117   P_Loss: -0.1738   V_Loss: 0.1049   S: 0.414
# Iter: 185/320   update: 58275   Loss: 0.3328   P_Loss: 0.2797   V_Loss: 0.0946   S: 0.446
#     0.99 vs. RAND    avg_len=8.39
#     0.55 vs. SELF    avg_len=16.01
#     0.54 vs. 1StepLA    avg_len=13.02
#         undoing last updates...
# Iter: 186/320   update: 58590   Loss: 0.142   P_Loss: 0.0828   V_Loss: 0.1033   S: 0.456
# Iter: 187/320   update: 58905   Loss: 0.0478   P_Loss: -0.0092   V_Loss: 0.0996   S: 0.443
# Iter: 188/320   update: 59220   Loss: 0.1565   P_Loss: 0.0957   V_Loss: 0.1063   S: 0.474
# Iter: 189/320   update: 59535   Loss: -0.0047   P_Loss: -0.0529   V_Loss: 0.0882   S: 0.449
# Iter: 190/320   update: 59850   Loss: 0.2634   P_Loss: 0.1941   V_Loss: 0.1138   S: 0.399
#     1.0 vs. RAND    avg_len=8.8
#     0.58 vs. SELF    avg_len=16.4
#     0.49 vs. 1StepLA    avg_len=12.35
#         undoing last updates...
# Iter: 191/320   update: 60165   Loss: 0.1209   P_Loss: 0.0431   V_Loss: 0.1267   S: 0.432
# Iter: 192/320   update: 60480   Loss: 0.095   P_Loss: 0.0305   V_Loss: 0.1103   S: 0.457
# Iter: 193/320   update: 60795   Loss: 0.1594   P_Loss: 0.1088   V_Loss: 0.0929   S: 0.478
# Iter: 194/320   update: 61110   Loss: 0.0265   P_Loss: -0.0282   V_Loss: 0.0957   S: 0.426
# Iter: 195/320   update: 61425   Loss: 0.0666   P_Loss: 0.0069   V_Loss: 0.1039   S: 0.457
#     0.99 vs. RAND    avg_len=8.13
#     0.6 vs. SELF    avg_len=15.77
#     0.57 vs. 1StepLA    avg_len=12.09
#         undoing last updates...
# Iter: 196/320   update: 61740   Loss: 0.0464   P_Loss: 0.0004   V_Loss: 0.0891   S: 0.521
# Iter: 197/320   update: 62055   Loss: 0.151   P_Loss: 0.0907   V_Loss: 0.1061   S: 0.481
# Iter: 198/320   update: 62370   Loss: 0.3481   P_Loss: 0.28   V_Loss: 0.114   S: 0.437
# Iter: 199/320   update: 62685   Loss: -0.0546   P_Loss: -0.1125   V_Loss: 0.1004   S: 0.436
# Iter: 200/320   update: 63000   Loss: 0.341   P_Loss: 0.2717   V_Loss: 0.1161   S: 0.442
#     1.0 vs. RAND    avg_len=8.84
#     0.4 vs. SELF    avg_len=14.82
#     0.63 vs. 1StepLA    avg_len=12.61
# Iter: 201/320   update: 63315   Loss: -0.0393   P_Loss: -0.0932   V_Loss: 0.0948   S: 0.429
# Iter: 202/320   update: 63630   Loss: 0.2965   P_Loss: 0.2335   V_Loss: 0.1093   S: 0.472
# Iter: 203/320   update: 63945   Loss: 0.0698   P_Loss: -0.0057   V_Loss: 0.1214   S: 0.389
# Iter: 204/320   update: 64260   Loss: 0.2645   P_Loss: 0.191   V_Loss: 0.1169   S: 0.355
# Iter: 205/320   update: 64575   Loss: 0.0377   P_Loss: -0.0322   V_Loss: 0.1136   S: 0.383
#     1.0 vs. RAND    avg_len=8.7
#     0.47 vs. SELF    avg_len=15.41
#     0.57 vs. 1StepLA    avg_len=12.99
#         undoing last updates...
# Iter: 206/320   update: 64890   Loss: 0.0608   P_Loss: 0.0044   V_Loss: 0.1004   S: 0.472
# Iter: 207/320   update: 65205   Loss: 0.2382   P_Loss: 0.184   V_Loss: 0.0969   S: 0.462
# Iter: 208/320   update: 65520   Loss: -0.0463   P_Loss: -0.0981   V_Loss: 0.0944   S: 0.474
# Iter: 209/320   update: 65835   Loss: 0.2294   P_Loss: 0.1426   V_Loss: 0.1384   S: 0.424
# Iter: 210/320   update: 66150   Loss: -0.011   P_Loss: -0.0795   V_Loss: 0.1156   S: 0.456
#     1.0 vs. RAND    avg_len=8.38
#     0.48 vs. SELF    avg_len=14.56
#     0.69 vs. 1StepLA    avg_len=13.19
#         new best checkpoints/PPO_Agent_69_vs_1StepLA_0905_1809.pt is saved!!!
# Iter: 211/320   update: 66465   Loss: 0.3161   P_Loss: 0.2524   V_Loss: 0.1081   S: 0.435
# Iter: 212/320   update: 66780   Loss: 0.4681   P_Loss: 0.4156   V_Loss: 0.0939   S: 0.448
# Iter: 213/320   update: 67095   Loss: 0.0569   P_Loss: -0.0003   V_Loss: 0.1001   S: 0.448
# Iter: 214/320   update: 67410   Loss: 0.2236   P_Loss: 0.1536   V_Loss: 0.1143   S: 0.392
# Iter: 215/320   update: 67725   Loss: 0.1255   P_Loss: 0.0693   V_Loss: 0.0974   S: 0.423
#     0.99 vs. RAND    avg_len=8.71
#     0.4 vs. SELF    avg_len=15.68
#     0.63 vs. 1StepLA    avg_len=13.01
# Iter: 216/320   update: 68040   Loss: 0.097   P_Loss: 0.0382   V_Loss: 0.0992   S: 0.391
# Iter: 217/320   update: 68355   Loss: 0.2381   P_Loss: 0.1595   V_Loss: 0.1247   S: 0.372
# Iter: 218/320   update: 68670   Loss: 0.0962   P_Loss: 0.04   V_Loss: 0.0954   S: 0.383
# Iter: 219/320   update: 68985   Loss: 0.107   P_Loss: 0.0488   V_Loss: 0.098   S: 0.381
# Iter: 220/320   update: 69300   Loss: 0.0842   P_Loss: 0.0344   V_Loss: 0.0871   S: 0.386
#     0.99 vs. RAND    avg_len=8.55
#     0.54 vs. SELF    avg_len=15.08
#     0.57 vs. 1StepLA    avg_len=12.51
#         undoing last updates...
# Iter: 221/320   update: 69615   Loss: 0.2813   P_Loss: 0.2252   V_Loss: 0.0985   S: 0.445
# Iter: 222/320   update: 69930   Loss: -0.125   P_Loss: -0.1844   V_Loss: 0.1022   S: 0.433
# Iter: 223/320   update: 70245   Loss: 0.3822   P_Loss: 0.3194   V_Loss: 0.1066   S: 0.43
# Iter: 224/320   update: 70560   Loss: -0.1495   P_Loss: -0.2103   V_Loss: 0.1039   S: 0.427
# Iter: 225/320   update: 70875   Loss: 0.3011   P_Loss: 0.2416   V_Loss: 0.1012   S: 0.41
#     0.99 vs. RAND    avg_len=8.43
#     0.54 vs. SELF    avg_len=15.1
#     0.66 vs. 1StepLA    avg_len=13.18
# Iter: 226/320   update: 71190   Loss: -0.0404   P_Loss: -0.0877   V_Loss: 0.0854   S: 0.419
# Iter: 227/320   update: 71505   Loss: 0.1107   P_Loss: 0.0515   V_Loss: 0.1022   S: 0.434
# Iter: 228/320   update: 71820   Loss: 0.1382   P_Loss: 0.0695   V_Loss: 0.1131   S: 0.402
# Iter: 229/320   update: 72135   Loss: 0.2052   P_Loss: 0.1471   V_Loss: 0.0986   S: 0.395
# Iter: 230/320   update: 72450   Loss: 0.0328   P_Loss: -0.0129   V_Loss: 0.0812   S: 0.379
#     0.98 vs. RAND    avg_len=8.56
#     0.39 vs. SELF    avg_len=15.35
#     0.47 vs. 1StepLA    avg_len=13.09
#         undoing last updates...
# Iter: 231/320   update: 72765   Loss: 0.3892   P_Loss: 0.3311   V_Loss: 0.1019   S: 0.457
# Iter: 232/320   update: 73080   Loss: -0.1381   P_Loss: -0.1899   V_Loss: 0.0918   S: 0.426
# Iter: 233/320   update: 73395   Loss: 0.3814   P_Loss: 0.3246   V_Loss: 0.0986   S: 0.431
# Iter: 234/320   update: 73710   Loss: -0.201   P_Loss: -0.2551   V_Loss: 0.0958   S: 0.445
# Iter: 235/320   update: 74025   Loss: 0.3103   P_Loss: 0.2577   V_Loss: 0.091   S: 0.392
#     0.99 vs. RAND    avg_len=8.33
#     0.46 vs. SELF    avg_len=15.7
#     0.64 vs. 1StepLA    avg_len=13.1
# Iter: 236/320   update: 74340   Loss: -0.0596   P_Loss: -0.1083   V_Loss: 0.0888   S: 0.447
# Iter: 237/320   update: 74655   Loss: 0.337   P_Loss: 0.2979   V_Loss: 0.075   S: 0.427
# Iter: 238/320   update: 74970   Loss: -0.0663   P_Loss: -0.1193   V_Loss: 0.0928   S: 0.417
# Iter: 239/320   update: 75285   Loss: 0.3193   P_Loss: 0.2509   V_Loss: 0.1139   S: 0.426
# Iter: 240/320   update: 75600   Loss: -0.1729   P_Loss: -0.2239   V_Loss: 0.0895   S: 0.403
#     0.99 vs. RAND    avg_len=8.49
#     0.37 vs. SELF    avg_len=14.69
#     0.56 vs. 1StepLA    avg_len=12.58
#         undoing last updates...
# Iter: 241/320   update: 75915   Loss: 0.2802   P_Loss: 0.2199   V_Loss: 0.1023   S: 0.411
# Iter: 242/320   update: 76230   Loss: -0.1052   P_Loss: -0.1552   V_Loss: 0.0895   S: 0.428
# Iter: 243/320   update: 76545   Loss: 0.224   P_Loss: 0.1662   V_Loss: 0.1005   S: 0.439
# Iter: 244/320   update: 76860   Loss: 0.0285   P_Loss: -0.0294   V_Loss: 0.0988   S: 0.405
# Iter: 245/320   update: 77175   Loss: 0.2829   P_Loss: 0.2315   V_Loss: 0.09   S: 0.402
#     1.0 vs. RAND    avg_len=8.9
#     0.6 vs. SELF    avg_len=15.16
#     0.63 vs. 1StepLA    avg_len=13.35
# Iter: 246/320   update: 77490   Loss: -0.048   P_Loss: -0.1107   V_Loss: 0.1048   S: 0.397
# Iter: 247/320   update: 77805   Loss: 0.1986   P_Loss: 0.142   V_Loss: 0.0981   S: 0.425
# Iter: 248/320   update: 78120   Loss: 0.13   P_Loss: 0.0689   V_Loss: 0.1012   S: 0.37
# Iter: 249/320   update: 78435   Loss: 0.1227   P_Loss: 0.0525   V_Loss: 0.112   S: 0.345
# Iter: 250/320   update: 78750   Loss: 0.2109   P_Loss: 0.1371   V_Loss: 0.1146   S: 0.305
#     0.98 vs. RAND    avg_len=8.52
#     0.55 vs. SELF    avg_len=15.55
#     0.6 vs. 1StepLA    avg_len=13.16
#         undoing last updates...
# Iter: 251/320   update: 79065   Loss: 0.2706   P_Loss: 0.2198   V_Loss: 0.0908   S: 0.432
# Iter: 252/320   update: 79380   Loss: -0.0875   P_Loss: -0.147   V_Loss: 0.1022   S: 0.43
# Iter: 253/320   update: 79695   Loss: 0.2484   P_Loss: 0.1975   V_Loss: 0.0906   S: 0.427
# Iter: 254/320   update: 80010   Loss: 0.0239   P_Loss: -0.0295   V_Loss: 0.0916   S: 0.383
# Iter: 255/320   update: 80325   Loss: 0.1449   P_Loss: 0.0906   V_Loss: 0.095   S: 0.425
#     0.98 vs. RAND    avg_len=8.78
#     0.51 vs. SELF    avg_len=14.51
#     0.63 vs. 1StepLA    avg_len=12.99
# Iter: 256/320   update: 80640   Loss: 0.1148   P_Loss: 0.0616   V_Loss: 0.0925   S: 0.403
# Iter: 257/320   update: 80955   Loss: 0.0988   P_Loss: 0.0407   V_Loss: 0.0985   S: 0.396
# Iter: 258/320   update: 81270   Loss: 0.0036   P_Loss: -0.0506   V_Loss: 0.0935   S: 0.397
# Iter: 259/320   update: 81585   Loss: 0.1461   P_Loss: 0.095   V_Loss: 0.0909   S: 0.427
# Iter: 260/320   update: 81900   Loss: 0.0525   P_Loss: 0.0097   V_Loss: 0.0779   S: 0.392
#     0.98 vs. RAND    avg_len=8.68
#     0.52 vs. SELF    avg_len=15.4
#     0.6 vs. 1StepLA    avg_len=12.84
#         undoing last updates...
# Iter: 261/320   update: 82215   Loss: 0.2422   P_Loss: 0.1928   V_Loss: 0.088   S: 0.416
# Iter: 262/320   update: 82530   Loss: -0.0872   P_Loss: -0.1376   V_Loss: 0.0902   S: 0.432
# Iter: 263/320   update: 82845   Loss: 0.3451   P_Loss: 0.2776   V_Loss: 0.1126   S: 0.424
# Iter: 264/320   update: 83160   Loss: -0.0551   P_Loss: -0.1079   V_Loss: 0.0935   S: 0.432
# Iter: 265/320   update: 83475   Loss: 0.2111   P_Loss: 0.1576   V_Loss: 0.0938   S: 0.42
#     1.0 vs. RAND    avg_len=8.32
#     0.49 vs. SELF    avg_len=15.35
#     0.62 vs. 1StepLA    avg_len=12.88
# Iter: 266/320   update: 83790   Loss: 0.0696   P_Loss: 0.013   V_Loss: 0.0986   S: 0.434
# Iter: 267/320   update: 84105   Loss: 0.1905   P_Loss: 0.1364   V_Loss: 0.0966   S: 0.461
# Iter: 268/320   update: 84420   Loss: 0.0285   P_Loss: -0.0278   V_Loss: 0.0983   S: 0.435
# Iter: 269/320   update: 84735   Loss: 0.1425   P_Loss: 0.0938   V_Loss: 0.0888   S: 0.447
# Iter: 270/320   update: 85050   Loss: 0.1452   P_Loss: 0.0871   V_Loss: 0.0995   S: 0.413
#     0.99 vs. RAND    avg_len=8.69
#     0.42 vs. SELF    avg_len=15.68
#     0.68 vs. 1StepLA    avg_len=12.94
# Iter: 271/320   update: 85365   Loss: 0.1129   P_Loss: 0.051   V_Loss: 0.1054   S: 0.428
# Iter: 272/320   update: 85680   Loss: 0.1791   P_Loss: 0.1234   V_Loss: 0.0974   S: 0.434
# Iter: 273/320   update: 85995   Loss: 0.1285   P_Loss: 0.085   V_Loss: 0.0808   S: 0.427
# Iter: 274/320   update: 86310   Loss: -0.0238   P_Loss: -0.0734   V_Loss: 0.0885   S: 0.421
# Iter: 275/320   update: 86625   Loss: 0.2078   P_Loss: 0.1441   V_Loss: 0.1053   S: 0.382
#     0.98 vs. RAND    avg_len=9.0
#     0.45 vs. SELF    avg_len=16.33
#     0.65 vs. 1StepLA    avg_len=12.07
# Iter: 276/320   update: 86940   Loss: 0.0647   P_Loss: 0.0067   V_Loss: 0.0966   S: 0.359
# Iter: 277/320   update: 87255   Loss: 0.2152   P_Loss: 0.153   V_Loss: 0.1018   S: 0.354
# Iter: 278/320   update: 87570   Loss: 0.0334   P_Loss: -0.0308   V_Loss: 0.1023   S: 0.312
# Iter: 279/320   update: 87885   Loss: 0.1623   P_Loss: 0.1129   V_Loss: 0.0818   S: 0.298
# Iter: 280/320   update: 88200   Loss: 0.1091   P_Loss: 0.0601   V_Loss: 0.0791   S: 0.258
#     0.99 vs. RAND    avg_len=8.77
#     0.45 vs. SELF    avg_len=15.21
#     0.46 vs. 1StepLA    avg_len=11.48
#         undoing last updates...
# Iter: 281/320   update: 88515   Loss: 0.295   P_Loss: 0.2228   V_Loss: 0.1175   S: 0.4
# Iter: 282/320   update: 88830   Loss: -0.0008   P_Loss: -0.0524   V_Loss: 0.0922   S: 0.439
# Iter: 283/320   update: 89145   Loss: 0.2093   P_Loss: 0.1506   V_Loss: 0.1   S: 0.407
# Iter: 284/320   update: 89460   Loss: 0.0639   P_Loss: 0.0142   V_Loss: 0.0869   S: 0.386
# Iter: 285/320   update: 89775   Loss: 0.1993   P_Loss: 0.1486   V_Loss: 0.0893   S: 0.406
#     0.99 vs. RAND    avg_len=7.91
#     0.38 vs. SELF    avg_len=15.92
#     0.62 vs. 1StepLA    avg_len=12.82
# Iter: 286/320   update: 90090   Loss: 0.0776   P_Loss: 0.028   V_Loss: 0.0868   S: 0.39
# Iter: 287/320   update: 90405   Loss: 0.0998   P_Loss: 0.056   V_Loss: 0.0789   S: 0.387
# Iter: 288/320   update: 90720   Loss: 0.0667   P_Loss: 0.0143   V_Loss: 0.0904   S: 0.384
# Iter: 289/320   update: 91035   Loss: 0.2945   P_Loss: 0.2385   V_Loss: 0.0972   S: 0.425
# Iter: 290/320   update: 91350   Loss: -0.1548   P_Loss: -0.1915   V_Loss: 0.071   S: 0.414
#     1.0 vs. RAND    avg_len=7.94
#     0.47 vs. SELF    avg_len=14.75
#     0.59 vs. 1StepLA    avg_len=12.51
#         undoing last updates...
# Iter: 291/320   update: 91665   Loss: 0.2669   P_Loss: 0.201   V_Loss: 0.1112   S: 0.437
# Iter: 292/320   update: 91980   Loss: -0.089   P_Loss: -0.1429   V_Loss: 0.094   S: 0.416
# Iter: 293/320   update: 92295   Loss: 0.2716   P_Loss: 0.2076   V_Loss: 0.1083   S: 0.429
# Iter: 294/320   update: 92610   Loss: -0.0236   P_Loss: -0.0678   V_Loss: 0.0826   S: 0.444
# Iter: 295/320   update: 92925   Loss: 0.2037   P_Loss: 0.1385   V_Loss: 0.1106   S: 0.444
#     1.0 vs. RAND    avg_len=8.04
#     0.52 vs. SELF    avg_len=14.18
#     0.55 vs. 1StepLA    avg_len=12.38
#         undoing last updates...
# Iter: 296/320   update: 93240   Loss: 0.2924   P_Loss: 0.2281   V_Loss: 0.1089   S: 0.434
# Iter: 297/320   update: 93555   Loss: -0.093   P_Loss: -0.1468   V_Loss: 0.094   S: 0.418
# Iter: 298/320   update: 93870   Loss: 0.2662   P_Loss: 0.2112   V_Loss: 0.0953   S: 0.412
# Iter: 299/320   update: 94185   Loss: 0.0581   P_Loss: -0.0013   V_Loss: 0.1026   S: 0.44
# Iter: 300/320   update: 94500   Loss: 0.1091   P_Loss: 0.0522   V_Loss: 0.0975   S: 0.405
#     1.0 vs. RAND    avg_len=8.46
#     0.48 vs. SELF    avg_len=15.52
#     0.64 vs. 1StepLA    avg_len=12.54
# Iter: 301/320   update: 94815   Loss: -0.0328   P_Loss: -0.08   V_Loss: 0.0851   S: 0.416
# Iter: 302/320   update: 95130   Loss: 0.3458   P_Loss: 0.2918   V_Loss: 0.0945   S: 0.422
# Iter: 303/320   update: 95445   Loss: -0.1204   P_Loss: -0.1727   V_Loss: 0.0921   S: 0.421
# Iter: 304/320   update: 95760   Loss: 0.3748   P_Loss: 0.3146   V_Loss: 0.1026   S: 0.418
# Iter: 305/320   update: 96075   Loss: -0.0076   P_Loss: -0.0624   V_Loss: 0.095   S: 0.411
#     0.98 vs. RAND    avg_len=8.68
#     0.44 vs. SELF    avg_len=16.32
#     0.62 vs. 1StepLA    avg_len=13.44
# Iter: 306/320   update: 96390   Loss: 0.2219   P_Loss: 0.156   V_Loss: 0.1093   S: 0.404
# Iter: 307/320   update: 96705   Loss: 0.005   P_Loss: -0.0591   V_Loss: 0.1089   S: 0.441
# Iter: 308/320   update: 97020   Loss: 0.1949   P_Loss: 0.1291   V_Loss: 0.1093   S: 0.407
# Iter: 309/320   update: 97335   Loss: -0.0362   P_Loss: -0.0865   V_Loss: 0.0898   S: 0.426
# Iter: 310/320   update: 97650   Loss: 0.5318   P_Loss: 0.4692   V_Loss: 0.1032   S: 0.368
#     1.0 vs. RAND    avg_len=8.62
#     0.42 vs. SELF    avg_len=14.94
#     0.57 vs. 1StepLA    avg_len=11.49
#         undoing last updates...
# Iter: 311/320   update: 97965   Loss: 0.328   P_Loss: 0.2646   V_Loss: 0.1048   S: 0.382
# Iter: 312/320   update: 98280   Loss: -0.0216   P_Loss: -0.0781   V_Loss: 0.0962   S: 0.391
# Iter: 313/320   update: 98595   Loss: 0.3592   P_Loss: 0.3173   V_Loss: 0.0759   S: 0.376
# Iter: 314/320   update: 98910   Loss: -0.0905   P_Loss: -0.1477   V_Loss: 0.0978   S: 0.403
# Iter: 315/320   update: 99225   Loss: 0.291   P_Loss: 0.2466   V_Loss: 0.0812   S: 0.413
#     0.99 vs. RAND    avg_len=8.99
#     0.51 vs. SELF    avg_len=17.24
#     0.55 vs. 1StepLA    avg_len=12.61
#         undoing last updates...
# Iter: 316/320   update: 99540   Loss: 0.4479   P_Loss: 0.3797   V_Loss: 0.1127   S: 0.409
# Iter: 317/320   update: 99855   Loss: 0.0503   P_Loss: -0.0024   V_Loss: 0.0914   S: 0.395
# Iter: 318/320   update: 100170   Loss: 0.2973   P_Loss: 0.2341   V_Loss: 0.1079   S: 0.441
# Iter: 319/320   update: 100485   Loss: 0.0605   P_Loss: -0.0003   V_Loss: 0.1025   S: 0.403
# Iter: 320/320   update: 100800   Loss: 0.1995   P_Loss: 0.1442   V_Loss: 0.0948   S: 0.393
#     0.99 vs. RAND    avg_len=8.43
#     0.53 vs. SELF    avg_len=15.83
#     0.63 vs. 1StepLA    avg_len=12.51

# %% [markdown]
# ## 7) Plot training results

# %%
def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

# %%
data = moving_average(total_losses[:100000], w=1000)
x_vals = [x/1000 for x in range(len(data))]

plt.plot(x_vals, data)
plt.title('PPO Training Loss')
plt.xlabel("updates (in thousands)")
plt.ylabel("loss")
#plt.gca().xaxis.set_major_locator(MultipleLocator(10))
#plt.gca().yaxis.set_major_locator(MultipleLocator(0.025))
plt.show()

# %%
#num_updates = 100000
#x_vals = range(0, num_updates, num_updates//len(history['vs_1StepLA_win_rate']))
#x_vals = [x/1000 for x in x_vals]
data = history['vs_1StepLA_win_rate']
x_vals = [x/1000 for x in range(len(data))]

plt.plot(x_vals, data)
plt.title('PPO win rate vs 1StepLA')
plt.xlabel("updates (in thousands)")
plt.ylabel("win rate")
#plt.gca().xaxis.set_major_locator(MultipleLocator(10000))
plt.axhline(1, linestyle='--', alpha=0.4)
plt.axhline(0.5, linestyle='--', alpha=0.4)
plt.ylim(0.35, 1.09)
#plt.xlim(0, 105)
plt.show()

# %%
#num_updates = 100000
#x_vals = range(0, num_updates, num_updates//len(history['vs_1StepLA_win_rate']))
#x_vals = [x/1000 for x in x_vals]
data = history['vs_old_self_avg_game_len']
x_vals = [x/1000 for x in range(len(data))]

plt.title('PPO self-play game length')
plt.plot(x_vals, data)
plt.xlabel("updates (in thousands)")
plt.ylabel("game length")
#plt.gca().xaxis.set_major_locator(MultipleLocator(10))
plt.axhline(42, linestyle='--', alpha=0.4)
plt.axhline(7, linestyle='--', alpha=0.4)
plt.ylim(-1, 45)
# Out:
# (-1.0, 45.0)
